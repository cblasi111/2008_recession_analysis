# %%
import pandas as pd
from pandas import to_numeric
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import plotly.plotly as py
import plotly.graph_objs as go

# %%
# File to Load 
gdp_data_to_load = "../Resources/GDP Per State.csv"

gdp_df = pd.read_csv(gdp_data_to_load)
gdp_df.dropna(inplace = True)

gdp_df.head()
# Out:
#     GeoFIPS          GeoName Region TableName  \
# 0   "00000"  United States *          SAGDP2N
# 1   "00000"  United States *          SAGDP2N
# 2   "00000"  United States *          SAGDP2N
# 3   "00000"  United States *          SAGDP2N
# 4   "00000"  United States *          SAGDP2N
#
#                            ComponentName                         Unit  \
# 0  Gross domestic product (GDP) by state  Millions of current dollars
# 1  Gross domestic product (GDP) by state  Millions of current dollars
# 2  Gross domestic product (GDP) by state  Millions of current dollars
# 3  Gross domestic product (GDP) by state  Millions of current dollars
# 4  Gross domestic product (GDP) by state  Millions of current dollars
#
#    IndustryId IndustryClassification  \
# 0         1.0                    ...
# 1         2.0                    ...
# 2         3.0                     11
# 3         4.0                111-112
# 4         5.0                113-115
#
# ...

# %%
#Grab state name and industries
state_name = [state for state in gdp_df["GeoName"]]
industry_list = [indsutry for indsutry in gdp_df["Description"]]

# %%
# Converting 2007 GDP
convert_2007 = []

for gdp in gdp_df["2007"]:
    if gdp=="(L)":
        convert_2007.append(0)
    else:
        convert_2007.append(float(gdp))
        
    
gdp_df["new_2007"]=convert_2007

# Grouping by state and sum it by state
grouped_gdp_2007 = gdp_df.groupby(["GeoName"])["new_2007"].sum()
grouped_gdp_2007
# Out:
# GeoName
# Alabama                   871458.0
# Alaska                    258519.1
# Arizona                  1364345.5
# Arkansas                  505808.7
# California              10292533.3
# Colorado                 1290626.7
# Connecticut              1281368.7
# Delaware                  306022.7
# District of Columbia      441922.8
# Far West                14220540.1
# Florida                  4003435.1
# Georgia                  2157946.5
# Great Lakes             10973481.9
# Hawaii                    327330.8
# Idaho                     279017.2
# Illinois                 3454991.5
# Indiana                  1452643.8
# Iowa                      734984.2
# Kansas                    638964.7
# Kentucky                  807294.0
# Louisiana                1107719.4
# Maine                     256019.0
# Maryland                 1456079.2
# Massachusetts            2026627.1
# Michigan                 2153496.8
# Mideast                 13617117.0
# ...

# %%
# Converting 2008 GDP
convert_2008 = []

for gdp in gdp_df["2008"]:
    if gdp=="(L)":
        convert_2008.append(0)
    else:
        convert_2008.append(float(gdp))
        
    
gdp_df["new_2008"]=convert_2008

# Grouping by state and sum it by state
grouped_gdp_2008 = gdp_df.groupby(["GeoName"])["new_2008"].sum()
grouped_gdp_2008
# Out:
# GeoName
# Alabama                   887464.8
# Alaska                    292201.8
# Arizona                  1350187.0
# Arkansas                  516470.4
# California              10503609.1
# Colorado                 1341405.2
# Connecticut              1298767.5
# Delaware                  296140.3
# District of Columbia      467694.1
# Far West                14526292.8
# Florida                  3914140.1
# Georgia                  2151324.1
# Great Lakes             10893048.1
# Hawaii                    334810.0
# Idaho                     289238.6
# Illinois                 3438746.0
# Indiana                  1471431.9
# Iowa                      728294.7
# Kansas                    666768.6
# Kentucky                  822714.2
# Louisiana                1154393.0
# Maine                     260522.7
# Maryland                 1496701.5
# Massachusetts            2069449.0
# Michigan                 2046701.1
# Mideast                 13784135.0
# ...

# %%
# Converting 2009 GDP
convert_2009 = []

for gdp in gdp_df["2009"]:
    if gdp=="(L)":
        convert_2009.append(0)
    else:
        convert_2009.append(float(gdp))
        
    
gdp_df["new_2009"]=convert_2009

# Grouping by state and sum it by state
grouped_gdp_2009 = gdp_df.groupby(["GeoName"])["new_2009"].sum()
grouped_gdp_2009
# Out:
# GeoName
# Alabama                   859615.8
# Alaska                    259429.8
# Arizona                  1273380.6
# Arkansas                  503562.1
# California              10128368.6
# Colorado                 1302556.6
# Connecticut              1274555.1
# Delaware                  308894.0
# District of Columbia      468997.9
# Far West                14029901.7
# Florida                  3778413.3
# Georgia                  2119497.2
# Great Lakes             10615656.3
# Hawaii                    327742.1
# Idaho                     280023.3
# Illinois                 3436525.7
# Indiana                  1404028.5
# Iowa                      723108.2
# Kansas                    647334.3
# Kentucky                  809094.3
# Louisiana                1097860.9
# Maine                     263894.7
# Maryland                 1526908.5
# Massachusetts            2087282.7
# Michigan                 1928197.9
# Mideast                 14061876.2
# ...

# %%
# Converting 2010 GDP
convert_2010 = []

for gdp in gdp_df["2010"]:
    if gdp=="(L)":
        convert_2010.append(0)
    else:
        convert_2010.append(float(gdp))
        
    
gdp_df["new_2010"]=convert_2010

# Grouping by state and sum it by state
grouped_gdp_2010 = gdp_df.groupby(["GeoName"])["new_2010"].sum()
grouped_gdp_2010
# Out:
# GeoName
# Alabama                   895916.8
# Alaska                    278173.4
# Arizona                  1297726.9
# Arkansas                  528989.9
# California              10422062.7
# Colorado                 1340689.3
# Connecticut              1281031.3
# Delaware                  312160.3
# District of Columbia      491715.1
# Far West                14457093.8
# Florida                  3846828.4
# Georgia                  2170592.2
# Great Lakes             11081332.8
# Hawaii                    341460.6
# Idaho                     288961.1
# Illinois                 3531857.2
# Indiana                  1514921.6
# Iowa                      752844.0
# Kansas                    666862.2
# Kentucky                  856831.9
# Louisiana                1206018.3
# Maine                     270347.1
# Maryland                 1596710.1
# Massachusetts            2191920.1
# Michigan                 2047446.6
# Mideast                 14661613.9
# ...

# %%
# Converting 2011 GDP
convert_2011 = []

for gdp in gdp_df["2011"]:
    if gdp=="(L)":
        convert_2011.append(0)
    else:
        convert_2011.append(float(gdp))
        
    
gdp_df["new_2011"]=convert_2011

# Grouping by state and sum it by state
grouped_gdp_2011 = gdp_df.groupby(["GeoName"])["new_2011"].sum()
grouped_gdp_2011
# Out:
# GeoName
# Alabama                   933486.7
# Alaska                    296906.4
# Arizona                  1352543.2
# Arkansas                  554165.7
# California              10840295.9
# Colorado                 1393966.6
# Connecticut              1272897.5
# Delaware                  328651.2
# District of Columbia      511421.4
# Far West                15039693.2
# Florida                  3904019.0
# Georgia                  2242578.1
# Great Lakes             11581547.3
# Hawaii                    352978.4
# Idaho                     296990.0
# Illinois                 3680781.9
# Indiana                  1563143.6
# Iowa                      786303.8
# Kansas                    710639.9
# Kentucky                  888398.0
# Louisiana                1224212.5
# Maine                     272126.5
# Maryland                 1654636.3
# Massachusetts            2273435.0
# Michigan                 2134966.2
# Mideast                 15021601.2
# ...

# %%
# Converting 2012 GDP
convert_2012 = []

for gdp in gdp_df["2012"]:
    if gdp=="(L)":
        convert_2012.append(0)
    else:
        convert_2012.append(float(gdp))
        
    
gdp_df["new_2012"]=convert_2012

# Grouping by state and sum it by state
grouped_gdp_2012 = gdp_df.groupby(["GeoName"])["new_2012"].sum()
grouped_gdp_2012
# Out:
# GeoName
# Alabama                   962169.8
# Alaska                    304040.3
# Arizona                  1409909.7
# Arkansas                  567182.7
# California              11378199.2
# Colorado                 1443071.5
# Connecticut              1312606.5
# Delaware                  338130.9
# District of Columbia      526651.7
# Far West                15745405.7
# Florida                  4033347.0
# Georgia                  2326628.9
# Great Lakes             12053669.5
# Hawaii                    369797.1
# Idaho                     303124.7
# Illinois                 3868285.2
# Indiana                  1610084.8
# Iowa                      842596.8
# Kansas                    738897.4
# Kentucky                  923848.1
# Louisiana                1251292.5
# Maine                     278040.3
# Maryland                 1691144.8
# Massachusetts            2387291.5
# Michigan                 2235281.4
# Mideast                 15823565.7
# ...

# %%
# Converting 2013 GDP
convert_2013 = []

for gdp in gdp_df["2013"]:
    if gdp=="(L)":
        convert_2013.append(0)
    else:
        convert_2013.append(float(gdp))
        
    
gdp_df["new_2013"]=convert_2013

# Grouping by state and sum it by state
grouped_gdp_2013 = gdp_df.groupby(["GeoName"])["new_2013"].sum()
grouped_gdp_2013
# Out:
# GeoName
# Alabama                   991891.2
# Alaska                    298100.1
# Arizona                  1444997.3
# Arkansas                  598103.1
# California              11988756.8
# Colorado                 1521437.2
# Connecticut              1324429.7
# Delaware                  330299.9
# District of Columbia      537351.2
# Far West                16497931.5
# Florida                  4208492.4
# Georgia                  2419589.0
# Great Lakes             12442445.1
# Hawaii                    382035.4
# Idaho                     320108.1
# Illinois                 3960759.6
# Indiana                  1675575.4
# Iowa                      857559.0
# Kansas                    751011.8
# Kentucky                  957857.9
# Louisiana                1222291.3
# Maine                     282413.6
# Maryland                 1723719.5
# Massachusetts            2435914.5
# Michigan                 2311640.6
# Mideast                 16197139.3
# ...

# %%
# Converting 2014 GDP
convert_2014 = []

for gdp in gdp_df["2014"]:
    if gdp=="(L)":
        convert_2014.append(0)
    else:
        convert_2014.append(float(gdp))
        
    
gdp_df["new_2014"]=convert_2014

# Grouping by state and sum it by state
grouped_gdp_2014 = gdp_df.groupby(["GeoName"])["new_2014"].sum()
grouped_gdp_2014
# Out:
# GeoName
# Alabama                  1004377.2
# Alaska                    290090.0
# Arizona                  1496149.6
# Arkansas                  615173.9
# California              12706845.5
# Colorado                 1616678.7
# Connecticut              1333932.1
# Delaware                  368947.8
# District of Columbia      563427.3
# Far West                17415312.4
# Florida                  4415519.0
# Georgia                  2550492.3
# Great Lakes             13010583.2
# Hawaii                    392335.5
# Idaho                     334119.1
# Illinois                 4107371.0
# Indiana                  1763865.7
# Iowa                      920009.2
# Kansas                    778005.8
# Kentucky                  980816.2
# Louisiana                1273663.4
# Maine                     293681.4
# Maryland                 1781973.9
# Massachusetts            2540041.3
# Michigan                 2400879.7
# Mideast                 16951368.3
# ...

# %%
# Converting 2015 GDP
convert_2015 = []

for gdp in gdp_df["2015"]:
    if gdp=="(L)":
        convert_2015.append(0)
    else:
        convert_2015.append(float(gdp))
        
    
gdp_df["new_2015"]=convert_2015

# Grouping by state and sum it by state
grouped_gdp_2015 = gdp_df.groupby(["GeoName"])["new_2015"].sum()
grouped_gdp_2015
# Out:
# GeoName
# Alabama                  1038134.9
# Alaska                    259840.1
# Arizona                  1565713.8
# Arkansas                  620497.5
# California              13547062.5
# Colorado                 1674526.9
# Connecticut              1391691.1
# Delaware                  390441.0
# District of Columbia      589897.1
# Far West                18527750.0
# Florida                  4714514.7
# Georgia                  2694428.2
# Great Lakes             13466881.1
# Hawaii                    417834.4
# Idaho                     347204.4
# Illinois                 4253862.5
# Indiana                  1787215.4
# Iowa                      954442.6
# Kansas                    797835.9
# Kentucky                 1010344.9
# Louisiana                1248439.5
# Maine                     302080.9
# Maryland                 1857127.6
# Massachusetts            2700001.0
# Michigan                 2536638.2
# Mideast                 17620382.6
# ...

# %%
# Converting 2016 GDP
convert_2016 = []

for gdp in gdp_df["2016"]:
    if gdp=="(L)":
        convert_2016.append(0)
    else:
        convert_2016.append(float(gdp))
        
    
gdp_df["new_2016"]=convert_2016

# Grouping by state and sum it by state
grouped_gdp_2016 = gdp_df.groupby(["GeoName"])["new_2016"].sum()
grouped_gdp_2016
# Out:
# GeoName
# Alabama                  1051999.2
# Alaska                    252970.3
# Arizona                  1642651.5
# Arkansas                  627689.2
# California              14103819.0
# Colorado                 1730990.3
# Connecticut              1410048.4
# Delaware                  385591.1
# District of Columbia      611985.5
# Far West                19296977.2
# Florida                  4951845.6
# Georgia                  2831905.8
# Great Lakes             13769303.3
# Hawaii                    434234.0
# Idaho                     362680.7
# Illinois                 4326539.1
# Indiana                  1832318.1
# Iowa                      964461.0
# Kansas                    820722.8
# Kentucky                 1026739.5
# Louisiana                1208589.8
# Maine                     313077.4
# Maryland                 1949520.7
# Massachusetts            2794583.2
# Michigan                 2624278.7
# Mideast                 18171561.5
# ...

# %%
# Converting 2017 GDP
convert_2017 = []

for gdp in gdp_df["2017"]:
    if gdp=="(L)":
        convert_2017.append(0)
    else:
        convert_2017.append(float(gdp))
        
    
gdp_df["new_2017"]=convert_2017

# Grouping by state and sum it by state
grouped_gdp_2017 = gdp_df.groupby(["GeoName"])["new_2017"].sum()
grouped_gdp_2017
# Out:
# GeoName
# Alabama                   1097250.4
# Alaska                     266457.7
# Arizona                   1723649.8
# Arkansas                   647430.5
# California               14890926.2
# Colorado                  1828562.6
# Connecticut               1424163.8
# Delaware                   395426.2
# District of Columbia       637511.9
# Far West                 20356597.8
# Florida                   5170783.2
# Georgia                   2957809.6
# Great Lakes              14217369.0
# Hawaii                     452266.4
# Idaho                      378953.5
# Illinois                  4438639.7
# Indiana                   1903617.2
# Iowa                       979089.7
# Kansas                     844579.4
# Kentucky                  1059098.1
# Louisiana                 1265653.8
# Maine                      324534.4
# Maryland                  2025167.0
# Massachusetts             2909402.8
# Michigan                  2707273.3
# Mideast                  18849412.8
# ...

# %%
# Converting 2018 GDP
convert_2018 = []

for gdp in gdp_df["2018"]:
    if gdp=="(D)":
        convert_2018.append(0)
    elif gdp=="(NA)":
        convert_2018.append(0)
    else:
        convert_2018.append(float(gdp))
        
    
gdp_df["new_2018"]=convert_2018

# Grouping by state and sum it by state
grouped_gdp_2018 = gdp_df.groupby(["GeoName"])["new_2018"].sum()
grouped_gdp_2018
# Out:
# GeoName
# Alabama                   979230.9
# Alaska                    233290.3
# Arizona                  1570997.7
# Arkansas                  581071.5
# California              13368804.1
# Colorado                 1661732.6
# Connecticut              1260220.9
# Delaware                  348124.4
# District of Columbia      545554.1
# Far West                18327302.1
# Florida                  4716555.9
# Georgia                  2652465.2
# Great Lakes             12781191.0
# Hawaii                    396835.2
# Idaho                     346660.0
# Illinois                 3993353.3
# Indiana                  1705848.6
# Iowa                      869907.1
# Kansas                    754850.9
# Kentucky                  939421.9
# Louisiana                1151984.7
# Maine                     290353.6
# Maryland                 1774345.2
# Massachusetts            2605897.0
# Michigan                 2428536.2
# Mideast                 16123170.6
# ...

# %%
# Create a dataframe
gdp_totals = pd.DataFrame({"GDP 2007": grouped_gdp_2007,
                            "GDP 2008": grouped_gdp_2008,
                            "GDP 2009": grouped_gdp_2009,
                            "GDP 2010": grouped_gdp_2010,
                            "GDP 2011": grouped_gdp_2011,
                            "GDP 2012": grouped_gdp_2012,
                            "GDP 2013": grouped_gdp_2013,
                            "GDP 2014": grouped_gdp_2014,
                            "GDP 2015": grouped_gdp_2015,
                            "GDP 2016": grouped_gdp_2016,
                            "GDP 2017": grouped_gdp_2017,
                            "GDP 2018": grouped_gdp_2018})

# %%
# Calculate the delta from a year by year perspective for each state
delta_07_08 = ((gdp_totals["GDP 2008"] - gdp_totals["GDP 2007"])/ gdp_totals["GDP 2007"])*100
delta_08_09 = ((gdp_totals["GDP 2009"] - gdp_totals["GDP 2008"])/ gdp_totals["GDP 2008"])*100
delta_09_10 = ((gdp_totals["GDP 2010"] - gdp_totals["GDP 2009"])/ gdp_totals["GDP 2009"])*100
delta_10_11 = ((gdp_totals["GDP 2011"] - gdp_totals["GDP 2010"])/ gdp_totals["GDP 2010"])*100
delta_11_12 = ((gdp_totals["GDP 2012"] - gdp_totals["GDP 2011"])/ gdp_totals["GDP 2011"])*100
delta_12_13 = ((gdp_totals["GDP 2013"] - gdp_totals["GDP 2012"])/ gdp_totals["GDP 2012"])*100
delta_13_14 = ((gdp_totals["GDP 2014"] - gdp_totals["GDP 2013"])/ gdp_totals["GDP 2013"])*100
delta_14_15 = ((gdp_totals["GDP 2015"] - gdp_totals["GDP 2014"])/ gdp_totals["GDP 2014"])*100
delta_15_16 = ((gdp_totals["GDP 2016"] - gdp_totals["GDP 2015"])/ gdp_totals["GDP 2015"])*100
delta_16_17 = ((gdp_totals["GDP 2017"] - gdp_totals["GDP 2016"])/ gdp_totals["GDP 2016"])*100
delta_17_18 = ((gdp_totals["GDP 2018"] - gdp_totals["GDP 2017"])/ gdp_totals["GDP 2017"])*100
total_delta = ((gdp_totals["GDP 2018"] - gdp_totals["GDP 2007"])/ gdp_totals["GDP 2007"])*100

# %%
gdp_complete = pd.DataFrame({"GDP 2007": grouped_gdp_2007, 
                             "GDP 2008": grouped_gdp_2008, 
                             "GDP 2009": grouped_gdp_2009, 
                             "GDP 2010": grouped_gdp_2010, 
                             "GDP 2011": grouped_gdp_2011, 
                             "GDP 2012": grouped_gdp_2012, 
                             "GDP 2013": grouped_gdp_2013, 
                             "GDP 2014": grouped_gdp_2014, 
                             "GDP 2015": grouped_gdp_2015, 
                             "GDP 2016": grouped_gdp_2016, 
                             "GDP 2017": grouped_gdp_2017, 
                             "GDP 2018": grouped_gdp_2018, 
                             "07-08 Delta": delta_07_08, 
                             "08-09 Delta": delta_08_09, 
                             "09-10 Delta": delta_09_10, 
                             "10-11 Delta": delta_10_11, 
                             "11-12 Delta": delta_11_12, 
                             "12-13 Delta": delta_12_13, 
                             "13-14 Delta": delta_13_14, 
                             "14-15 Delta": delta_14_15, 
                             "15-16 Delta": delta_15_16, 
                             "16-17 Delta": delta_16_17, 
                             "17-18 Delta": delta_17_18, 
                             "Total Delta": total_delta})

#gdp_complete.drop(["Far West", "Great Lakes", "Mideast", "New England", "Plains", 
                   #"Rocky Mountain", "Southeast", "Southwest"])
gdp_complete = gdp_complete.reset_index()
gdp_complete
# Out:
#                  GeoName    GDP 2007    GDP 2008    GDP 2009    GDP 2010  \
# 0                Alabama    871458.0    887464.8    859615.8    895916.8
# 1                 Alaska    258519.1    292201.8    259429.8    278173.4
# 2                Arizona   1364345.5   1350187.0   1273380.6   1297726.9
# 3               Arkansas    505808.7    516470.4    503562.1    528989.9
# 4             California  10292533.3  10503609.1  10128368.6  10422062.7
# 5               Colorado   1290626.7   1341405.2   1302556.6   1340689.3
# 6            Connecticut   1281368.7   1298767.5   1274555.1   1281031.3
# 7               Delaware    306022.7    296140.3    308894.0    312160.3
# 8   District of Columbia    441922.8    467694.1    468997.9    491715.1
# 9               Far West  14220540.1  14526292.8  14029901.7  14457093.8
# 10               Florida   4003435.1   3914140.1   3778413.3   3846828.4
# 11               Georgia   2157946.5   2151324.1   2119497.2   2170592.2
# ...

# %%
# Create dataframe to show 07-08 change and 08-18 change
gdp_change_07_08 = gdp_complete["09-10 Delta"]
gdp_change_08_18 = ((gdp_complete["GDP 2018"] - gdp_complete["GDP 2008"])/ gdp_complete["GDP 2008"])*100
state_name = [state for state in gdp_complete["GeoName"]]



gdp_for_visualization = pd.DataFrame({"State": state_name, 
                                      "GDP Change (2007-2008)": gdp_change_07_08, 
                                      "GDP Change (2008-2018)": gdp_change_08_18})


gdp_for_visualization
# Out:
#                    State  GDP Change (2007-2008)  GDP Change (2008-2018)
# 0                Alabama                4.222933               10.340252
# 1                 Alaska                7.224922              -20.161238
# 2                Arizona                1.911942               16.354083
# 3               Arkansas                5.049586               12.508190
# 4             California                2.899718               27.278195
# 5               Colorado                2.927527               23.879988
# 6            Connecticut                0.508115               -2.967937
# 7               Delaware                1.057418               17.553876
# 8   District of Columbia                4.843774               16.647634
# 9               Far West                3.044869               26.166410
# 10               Florida                1.810683               20.500436
# 11               Georgia                2.410713               23.294542
# ...

# %%
print("Top performing states from 2007-2008")
top_performing_states_07_08 = gdp_for_visualization.sort_values(["GDP Change (2007-2008)"],ascending = False).head(5)
print(top_performing_states_07_08)

print("Bottom performing states from 2007-2008")
bottom_performing_states_07_08 = gdp_for_visualization.sort_values(["GDP Change (2007-2008)"],ascending = True).head(5)
print(bottom_performing_states_07_08)

print("Top performing states from 2008-2018")
top_performing_states_08_18 = gdp_for_visualization.sort_values(["GDP Change (2008-2018)"],ascending = False).head(5)
print(top_performing_states_08_18)

print("Bottom performing states from 2008-2018")
bottom_performing_states_08_18 = gdp_for_visualization.sort_values(["GDP Change (2008-2018)"],ascending = True).head(5)
print(bottom_performing_states_08_18)
# Out:
# Top performing states from 2007-2008
#            State  GDP Change (2007-2008)  GDP Change (2008-2018)
# 38  North Dakota               10.948377               49.009513
# 20     Louisiana                9.851649               -0.208620
# 16       Indiana                7.898209               15.931196
# 1         Alaska                7.224922              -20.161238
# 51         Texas                6.799134               23.116037
# Bottom performing states from 2007-2008
#           State  GDP Change (2007-2008)  GDP Change (2008-2018)
# 6   Connecticut                0.508115               -2.967937
# 7      Delaware                1.057418               17.553876
# 10      Florida                1.810683               20.500436
# 2       Arizona                1.911942               16.354083
# 34   New Jersey                1.994385                9.306080
# Top performing states from 2008-2018
#            State  GDP Change (2007-2008)  GDP Change (2008-2018)
# ...

# %%
data = [go.Choropleth(
    locations = state_name,
    z = gdp_for_visualization["GDP Change (2007-2008)"],
    text = gdp_for_visualization["State"],
    colorscale = [
        [0, "rgb(5, 10, 172)"],
        [0.35, "rgb(40, 60, 190)"],
        [0.5, "rgb(70, 100, 245)"],
        [0.6, "rgb(90, 120, 245)"],
        [0.7, "rgb(106, 137, 247)"],
        [1, "rgb(220, 220, 220)"]
    ],
    autocolorscale = False,
    reversescale = True,
    marker = go.choropleth.Marker(
        line = go.choropleth.marker.Line(
            color = 'rgb(180,180,180)',
            width = 0.5
        )),
    colorbar = go.choropleth.ColorBar(
        tickprefix = '%',
        title = 'Rate'),
)]

layout = go.Layout(
    title = go.layout.Title(
        text = "GDP Change (2007-2008)"
    ),
    geo = go.layout.Geo(
        showframe = False,
        showcoastlines = False,
        projection = go.layout.geo.Projection(
            type = 'equirectangular'
        )
    ),
    annotations = [go.layout.Annotation(
        x = 0.55,
        y = 0.1,
        xref = 'paper',
        yref = 'paper',
        showarrow = False
    )]
)

fig = go.Figure(data = data, layout = layout)
py.iplot(fig, filename = 'd3-world-map')
# Out:
# Aw, snap! We didn't get a username with your request.
#
# Don't have an account? https://plot.ly/api_signup
#
# Questions? accounts@plot.ly
# ---------------------------------------------------------------------------
# PlotlyError                               Traceback (most recent call last)
# <ipython-input-28-13cb71f37064> in <module>
#      44
#      45 fig = go.Figure(data = data, layout = layout)
# ---> 46 py.iplot(fig, filename = 'd3-world-map')
#
# ~\Anaconda1\lib\site-packages\chart_studio\plotly\plotly.py in iplot(figure_or_data, **plot_options)
#     185         embed_options['height'] = str(embed_options['height']) + 'px'
#     186
# --> 187     return tools.embed(url, **embed_options)
#     188
#     189
#
# ~\Anaconda1\lib\site-packages\chart_studio\tools.py in embed(file_owner_or_url, file_id, width, height)
#     362         else:
#     363             url = file_owner_or_url
# --> 364         return PlotlyDisplay(url, width, height)
#     365     else:
# ...
