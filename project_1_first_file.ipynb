# %%
# %matplotlib notebook

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
pop_file = "Resources/Population Estimates.csv"
pop_file_df = pd.read_csv(pop_file, skiprows=[0])
pop_file_df.head()
# Out:
#   These data were posted to the ERS website (at https://www.ers.usda.gov/data-products/county-level-data-sets/download-data.aspx) May 2019. Contact: Tim Parker, ERS/USDA, timothy.parker@usda.gov, (202) 694-5435.  \
# 0                                               FIPS
# 1                                              00000
# 2                                              01000
# 3                                              01001
# 4                                              01003
#
#   Unnamed: 1      Unnamed: 2                       Unnamed: 3  \
# 0      State       Area_Name  Rural-urban_Continuum Code_2003
# 1         US   United States                              NaN
# 2         AL         Alabama                              NaN
# 3         AL  Autauga County                                2
# 4         AL  Baldwin County                                4
#
#                         Unnamed: 4                 Unnamed: 5  \
# 0  Rural-urban_Continuum Code_2013  Urban_Influence_Code_2003
# 1                              NaN                        NaN
# 2                              NaN                        NaN
# 3                                2                          2
# 4                                3                          5
#
#                   Unnamed: 6              Unnamed: 7       Unnamed: 8  \
# 0  Urban_Influence_Code_2013  Economic_typology_2015  CENSUS_2010_POP
# 1                        NaN                     NaN      308,745,538
# 2                        NaN                     NaN        4,779,736
# 3                          2                       0           54,571
# 4                          2                       5          182,265
#
#             Unnamed: 9  ...         Unnamed: 139         Unnamed: 140  \
# 0  ESTIMATES_BASE_2010  ...  R_DOMESTIC_MIG_2017  R_DOMESTIC_MIG_2018
# 1          308,758,105  ...                  NaN                  NaN
# 2            4,780,138  ...                  0.4                  1.2
# 3               54,574  ...                  1.1                  0.7
# 4              182,264  ...                 22.0                 24.3
#
#      Unnamed: 141    Unnamed: 142    Unnamed: 143    Unnamed: 144  \
# 0  R_NET_MIG_2011  R_NET_MIG_2012  R_NET_MIG_2013  R_NET_MIG_2014
# 1             NaN             NaN             NaN             NaN
# 2             0.5             1.2             1.6             0.6
# 3             6.0            -6.1            -3.9             2.0
# 4            16.3            17.6            22.9            20.2
#
#      Unnamed: 145    Unnamed: 146    Unnamed: 147    Unnamed: 148
# 0  R_NET_MIG_2015  R_NET_MIG_2016  R_NET_MIG_2017  R_NET_MIG_2018
# 1             NaN             NaN             NaN             NaN
# 2             0.6             0.8             1.1             1.9
# 3            -1.9             5.3             1.0             0.6
# 4            17.9            21.5            22.5            24.8
#
# [5 rows x 149 columns]

# %%
pop_df = pop_file_df.set_index("These data were posted to the ERS website (at https://www.ers.usda.gov/data-products/county-level-data-sets/download-data.aspx) May 2019. Contact: Tim Parker, ERS/USDA, timothy.parker@usda.gov, (202) 694-5435.")
pop_df.head()
# Out:
#                                                    Unnamed: 1      Unnamed: 2  \
# These data were posted to the ERS website (at h...
# FIPS                                                    State       Area_Name
# 00000                                                      US   United States
# 01000                                                      AL         Alabama
# 01001                                                      AL  Autauga County
# 01003                                                      AL  Baldwin County
#
#                                                                          Unnamed: 3  \
# These data were posted to the ERS website (at h...
# FIPS                                                Rural-urban_Continuum Code_2003
# 00000                                                                           NaN
# 01000                                                                           NaN
# 01001                                                                             2
# 01003                                                                             4
#
#                                                                          Unnamed: 4  \
# These data were posted to the ERS website (at h...
# FIPS                                                Rural-urban_Continuum Code_2013
# 00000                                                                           NaN
# 01000                                                                           NaN
# 01001                                                                             2
# 01003                                                                             3
#
#                                                                    Unnamed: 5  \
# These data were posted to the ERS website (at h...
# FIPS                                                Urban_Influence_Code_2003
# 00000                                                                     NaN
# 01000                                                                     NaN
# 01001                                                                       2
# 01003                                                                       5
#
#                                                                    Unnamed: 6  \
# These data were posted to the ERS website (at h...
# FIPS                                                Urban_Influence_Code_2013
# 00000                                                                     NaN
# 01000                                                                     NaN
# 01001                                                                       2
# 01003                                                                       2
#
#                                                                 Unnamed: 7  \
# These data were posted to the ERS website (at h...
# FIPS                                                Economic_typology_2015
# 00000                                                                  NaN
# 01000                                                                  NaN
# 01001                                                                    0
# 01003                                                                    5
#
#                                                          Unnamed: 8  \
# These data were posted to the ERS website (at h...
# FIPS                                                CENSUS_2010_POP
# 00000                                                   308,745,538
# 01000                                                     4,779,736
# 01001                                                        54,571
# 01003                                                       182,265
#
#                                                              Unnamed: 9  \
# These data were posted to the ERS website (at h...
# FIPS                                                ESTIMATES_BASE_2010
# 00000                                                       308,758,105
# 01000                                                         4,780,138
# 01001                                                            54,574
# 01003                                                           182,264
#
#                                                           Unnamed: 10  ...  \
# These data were posted to the ERS website (at h...                     ...
# FIPS                                                POP_ESTIMATE_2010  ...
# 00000                                                     309,326,085  ...
# 01000                                                       4,785,448  ...
# 01001                                                          54,754  ...
# 01003                                                         183,111  ...
#
#                                                            Unnamed: 139  \
# These data were posted to the ERS website (at h...
# FIPS                                                R_DOMESTIC_MIG_2017
# 00000                                                               NaN
# 01000                                                               0.4
# 01001                                                               1.1
# 01003                                                              22.0
#
#                                                            Unnamed: 140  \
# These data were posted to the ERS website (at h...
# FIPS                                                R_DOMESTIC_MIG_2018
# 00000                                                               NaN
# 01000                                                               1.2
# 01001                                                               0.7
# 01003                                                              24.3
#
#                                                       Unnamed: 141  \
# These data were posted to the ERS website (at h...
# FIPS                                                R_NET_MIG_2011
# 00000                                                          NaN
# 01000                                                          0.5
# 01001                                                          6.0
# 01003                                                         16.3
#
#                                                       Unnamed: 142  \
# These data were posted to the ERS website (at h...
# FIPS                                                R_NET_MIG_2012
# 00000                                                          NaN
# 01000                                                          1.2
# 01001                                                         -6.1
# 01003                                                         17.6
#
#                                                       Unnamed: 143  \
# These data were posted to the ERS website (at h...
# FIPS                                                R_NET_MIG_2013
# 00000                                                          NaN
# 01000                                                          1.6
# 01001                                                         -3.9
# 01003                                                         22.9
#
#                                                       Unnamed: 144  \
# These data were posted to the ERS website (at h...
# FIPS                                                R_NET_MIG_2014
# 00000                                                          NaN
# 01000                                                          0.6
# 01001                                                          2.0
# 01003                                                         20.2
#
#                                                       Unnamed: 145  \
# These data were posted to the ERS website (at h...
# FIPS                                                R_NET_MIG_2015
# 00000                                                          NaN
# 01000                                                          0.6
# 01001                                                         -1.9
# 01003                                                         17.9
#
#                                                       Unnamed: 146  \
# These data were posted to the ERS website (at h...
# FIPS                                                R_NET_MIG_2016
# 00000                                                          NaN
# 01000                                                          0.8
# 01001                                                          5.3
# 01003                                                         21.5
#
#                                                       Unnamed: 147  \
# These data were posted to the ERS website (at h...
# FIPS                                                R_NET_MIG_2017
# 00000                                                          NaN
# 01000                                                          1.1
# 01001                                                          1.0
# 01003                                                         22.5
#
#                                                       Unnamed: 148
# These data were posted to the ERS website (at h...
# FIPS                                                R_NET_MIG_2018
# 00000                                                          NaN
# 01000                                                          1.9
# 01001                                                          0.6
# 01003                                                         24.8
#
# [5 rows x 148 columns]

# %%
pop_df = pop_df.dropna(how='all')
pop_df.head()
# Out:
#                                                    Unnamed: 1      Unnamed: 2  \
# These data were posted to the ERS website (at h...
# FIPS                                                    State       Area_Name
# 00000                                                      US   United States
# 01000                                                      AL         Alabama
# 01001                                                      AL  Autauga County
# 01003                                                      AL  Baldwin County
#
#                                                                          Unnamed: 3  \
# These data were posted to the ERS website (at h...
# FIPS                                                Rural-urban_Continuum Code_2003
# 00000                                                                           NaN
# 01000                                                                           NaN
# 01001                                                                             2
# 01003                                                                             4
#
#                                                                          Unnamed: 4  \
# These data were posted to the ERS website (at h...
# FIPS                                                Rural-urban_Continuum Code_2013
# 00000                                                                           NaN
# 01000                                                                           NaN
# 01001                                                                             2
# 01003                                                                             3
#
#                                                                    Unnamed: 5  \
# These data were posted to the ERS website (at h...
# FIPS                                                Urban_Influence_Code_2003
# 00000                                                                     NaN
# 01000                                                                     NaN
# 01001                                                                       2
# 01003                                                                       5
#
#                                                                    Unnamed: 6  \
# These data were posted to the ERS website (at h...
# FIPS                                                Urban_Influence_Code_2013
# 00000                                                                     NaN
# 01000                                                                     NaN
# 01001                                                                       2
# 01003                                                                       2
#
#                                                                 Unnamed: 7  \
# These data were posted to the ERS website (at h...
# FIPS                                                Economic_typology_2015
# 00000                                                                  NaN
# 01000                                                                  NaN
# 01001                                                                    0
# 01003                                                                    5
#
#                                                          Unnamed: 8  \
# These data were posted to the ERS website (at h...
# FIPS                                                CENSUS_2010_POP
# 00000                                                   308,745,538
# 01000                                                     4,779,736
# 01001                                                        54,571
# 01003                                                       182,265
#
#                                                              Unnamed: 9  \
# These data were posted to the ERS website (at h...
# FIPS                                                ESTIMATES_BASE_2010
# 00000                                                       308,758,105
# 01000                                                         4,780,138
# 01001                                                            54,574
# 01003                                                           182,264
#
#                                                           Unnamed: 10  ...  \
# These data were posted to the ERS website (at h...                     ...
# FIPS                                                POP_ESTIMATE_2010  ...
# 00000                                                     309,326,085  ...
# 01000                                                       4,785,448  ...
# 01001                                                          54,754  ...
# 01003                                                         183,111  ...
#
#                                                            Unnamed: 139  \
# These data were posted to the ERS website (at h...
# FIPS                                                R_DOMESTIC_MIG_2017
# 00000                                                               NaN
# 01000                                                               0.4
# 01001                                                               1.1
# 01003                                                              22.0
#
#                                                            Unnamed: 140  \
# These data were posted to the ERS website (at h...
# FIPS                                                R_DOMESTIC_MIG_2018
# 00000                                                               NaN
# 01000                                                               1.2
# 01001                                                               0.7
# 01003                                                              24.3
#
#                                                       Unnamed: 141  \
# These data were posted to the ERS website (at h...
# FIPS                                                R_NET_MIG_2011
# 00000                                                          NaN
# 01000                                                          0.5
# 01001                                                          6.0
# 01003                                                         16.3
#
#                                                       Unnamed: 142  \
# These data were posted to the ERS website (at h...
# FIPS                                                R_NET_MIG_2012
# 00000                                                          NaN
# 01000                                                          1.2
# 01001                                                         -6.1
# 01003                                                         17.6
#
#                                                       Unnamed: 143  \
# These data were posted to the ERS website (at h...
# FIPS                                                R_NET_MIG_2013
# 00000                                                          NaN
# 01000                                                          1.6
# 01001                                                         -3.9
# 01003                                                         22.9
#
#                                                       Unnamed: 144  \
# These data were posted to the ERS website (at h...
# FIPS                                                R_NET_MIG_2014
# 00000                                                          NaN
# 01000                                                          0.6
# 01001                                                          2.0
# 01003                                                         20.2
#
#                                                       Unnamed: 145  \
# These data were posted to the ERS website (at h...
# FIPS                                                R_NET_MIG_2015
# 00000                                                          NaN
# 01000                                                          0.6
# 01001                                                         -1.9
# 01003                                                         17.9
#
#                                                       Unnamed: 146  \
# These data were posted to the ERS website (at h...
# FIPS                                                R_NET_MIG_2016
# 00000                                                          NaN
# 01000                                                          0.8
# 01001                                                          5.3
# 01003                                                         21.5
#
#                                                       Unnamed: 147  \
# These data were posted to the ERS website (at h...
# FIPS                                                R_NET_MIG_2017
# 00000                                                          NaN
# 01000                                                          1.1
# 01001                                                          1.0
# 01003                                                         22.5
#
#                                                       Unnamed: 148
# These data were posted to the ERS website (at h...
# FIPS                                                R_NET_MIG_2018
# 00000                                                          NaN
# 01000                                                          1.9
# 01001                                                          0.6
# 01003                                                         24.8
#
# [5 rows x 148 columns]

# %%
somerset_county = pop_df.loc["34035", "Unnamed: 64"]
print("Somerset County's Net domestic migration period from 4/1/2010 to 6/30/2010 is " + somerset_county + " people.")

monmouth_county = pop_df.loc["34025", "Unnamed: 64"]
print("Monmouth County's Net domestic migration period from 4/1/2010 to 6/30/2010 is " + monmouth_county + " people.")

essex_county = pop_df.loc["34013", "Unnamed: 64"]
print("Essex County's Net domestic migration period from 4/1/2010 to 6/30/2010 is " + essex_county + " people.")

cape_may_county = pop_df.loc["34009", "Unnamed: 64"]
print("Cape May County's Net domestic migration period from 4/1/2010 to 6/30/2010 is " + cape_may_county + " people.")

bergen_county = pop_df.loc["34003", "Unnamed: 64"]
print("Bergen County's Net domestic migration period from 4/1/2010 to 6/30/2010 is " + bergen_county + " people.")
# Out:
# Somerset County's Net domestic migration period from 4/1/2010 to 6/30/2010 is 34 people.
# Monmouth County's Net domestic migration period from 4/1/2010 to 6/30/2010 is -328 people.
# Essex County's Net domestic migration period from 4/1/2010 to 6/30/2010 is -1,913 people.
# Cape May County's Net domestic migration period from 4/1/2010 to 6/30/2010 is 52 people.
# Bergen County's Net domestic migration period from 4/1/2010 to 6/30/2010 is -76 people.

# %%
nj_top_pop_stats = pop_df.loc[["34035", "34025", "34013", "34009", "34003"], ["Unnamed: 64", "Unnamed: 19", "Unnamed: 8"]]
# 34035 = somerset, 34025 = monmouth, 34013 = essex, 34009 = capemay, 34003 = bergen
# Unnamed 64 = net domestic migration, unnamed 19 = numeric change in resident total population , unnamed 8 = resident Census population
print(nj_top_pop_stats)
print()
# Out:
#                                                    Unnamed: 64 Unnamed: 19  \
# These data were posted to the ERS website (at h...
# 34035                                                       34         651
# 34025                                                     -328         106
# 34013                                                   -1,913         177
# 34009                                                       52         -40
# 34003                                                      -76       1,198
#
#                                                    Unnamed: 8
# These data were posted to the ERS website (at h...
# 34035                                                 323,444
# 34025                                                 630,380
# 34013                                                 783,969
# 34009                                                  97,265
# 34003                                                 905,116

# %%
nj_total_pop_stats = pop_df.loc[["34000"], ["Unnamed: 64", "Unnamed: 19", "Unnamed: 8"]]
# 34000 = NJ
# Unnamed 64 = net domestic migration, unnamed 19 = numeric change in resident total population , unnamed 8 = resident Census population
print(nj_total_pop_stats)
print()
# Out:
#                                                    Unnamed: 64 Unnamed: 19  \
# These data were posted to the ERS website (at h...
# 34000                                                   -8,758       7,662
#
#                                                    Unnamed: 8
# These data were posted to the ERS website (at h...
# 34000                                               8,791,894

# %%
new_header = pop_df.iloc[0]
pop_df = pop_df[1:]
pop_df.columns = new_header

# %%
pop_df.head()
# Out:
# FIPS                                               State       Area_Name  \
# These data were posted to the ERS website (at h...
# 00000                                                 US   United States
# 01000                                                 AL         Alabama
# 01001                                                 AL  Autauga County
# 01003                                                 AL  Baldwin County
# 01005                                                 AL  Barbour County
#
# FIPS                                               Rural-urban_Continuum Code_2003  \
# These data were posted to the ERS website (at h...
# 00000                                                                          NaN
# 01000                                                                          NaN
# 01001                                                                            2
# 01003                                                                            4
# 01005                                                                            6
#
# FIPS                                               Rural-urban_Continuum Code_2013  \
# These data were posted to the ERS website (at h...
# 00000                                                                          NaN
# 01000                                                                          NaN
# 01001                                                                            2
# 01003                                                                            3
# 01005                                                                            6
#
# FIPS                                               Urban_Influence_Code_2003  \
# These data were posted to the ERS website (at h...
# 00000                                                                    NaN
# 01000                                                                    NaN
# 01001                                                                      2
# 01003                                                                      5
# 01005                                                                      6
#
# FIPS                                               Urban_Influence_Code_2013  \
# These data were posted to the ERS website (at h...
# 00000                                                                    NaN
# 01000                                                                    NaN
# 01001                                                                      2
# 01003                                                                      2
# 01005                                                                      6
#
# FIPS                                               Economic_typology_2015  \
# These data were posted to the ERS website (at h...
# 00000                                                                 NaN
# 01000                                                                 NaN
# 01001                                                                   0
# 01003                                                                   5
# 01005                                                                   3
#
# FIPS                                               CENSUS_2010_POP  \
# These data were posted to the ERS website (at h...
# 00000                                                  308,745,538
# 01000                                                    4,779,736
# 01001                                                       54,571
# 01003                                                      182,265
# 01005                                                       27,457
#
# FIPS                                               ESTIMATES_BASE_2010  \
# These data were posted to the ERS website (at h...
# 00000                                                      308,758,105
# 01000                                                        4,780,138
# 01001                                                           54,574
# 01003                                                          182,264
# 01005                                                           27,457
#
# FIPS                                               POP_ESTIMATE_2010  ...  \
# These data were posted to the ERS website (at h...                    ...
# 00000                                                    309,326,085  ...
# 01000                                                      4,785,448  ...
# 01001                                                         54,754  ...
# 01003                                                        183,111  ...
# 01005                                                         27,330  ...
#
# FIPS                                               R_DOMESTIC_MIG_2017  \
# These data were posted to the ERS website (at h...
# 00000                                                              NaN
# 01000                                                              0.4
# 01001                                                              1.1
# 01003                                                             22.0
# 01005                                                            -25.5
#
# FIPS                                               R_DOMESTIC_MIG_2018  \
# These data were posted to the ERS website (at h...
# 00000                                                              NaN
# 01000                                                              1.2
# 01001                                                              0.7
# 01003                                                             24.3
# 01005                                                             -9.1
#
# FIPS                                               R_NET_MIG_2011  \
# These data were posted to the ERS website (at h...
# 00000                                                         NaN
# 01000                                                         0.5
# 01001                                                         6.0
# 01003                                                        16.3
# 01005                                                         0.3
#
# FIPS                                               R_NET_MIG_2012  \
# These data were posted to the ERS website (at h...
# 00000                                                         NaN
# 01000                                                         1.2
# 01001                                                        -6.1
# 01003                                                        17.6
# 01005                                                        -6.8
#
# FIPS                                               R_NET_MIG_2013  \
# These data were posted to the ERS website (at h...
# 00000                                                         NaN
# 01000                                                         1.6
# 01001                                                        -3.9
# 01003                                                        22.9
# 01005                                                        -8.1
#
# FIPS                                               R_NET_MIG_2014  \
# These data were posted to the ERS website (at h...
# 00000                                                         NaN
# 01000                                                         0.6
# 01001                                                         2.0
# 01003                                                        20.2
# 01005                                                        -5.1
#
# FIPS                                               R_NET_MIG_2015  \
# These data were posted to the ERS website (at h...
# 00000                                                         NaN
# 01000                                                         0.6
# 01001                                                        -1.9
# 01003                                                        17.9
# 01005                                                       -15.5
#
# FIPS                                               R_NET_MIG_2016  \
# These data were posted to the ERS website (at h...
# 00000                                                         NaN
# 01000                                                         0.8
# 01001                                                         5.3
# 01003                                                        21.5
# 01005                                                       -18.2
#
# FIPS                                               R_NET_MIG_2017  \
# These data were posted to the ERS website (at h...
# 00000                                                         NaN
# 01000                                                         1.1
# 01001                                                         1.0
# 01003                                                        22.5
# 01005                                                       -25.0
#
# FIPS                                               R_NET_MIG_2018
# These data were posted to the ERS website (at h...
# 00000                                                         NaN
# 01000                                                         1.9
# 01001                                                         0.6
# 01003                                                        24.8
# 01005                                                        -8.6
#
# [5 rows x 148 columns]

# %%
state_pop = pop_df.loc[[
    "01000", "02000", "04000", "05000", "06000", "08000", "09000", "10000", "11000", "12000", "13000"], ["CENSUS_2010_POP", "POP_ESTIMATE_2010", "N_POP_CHG_2010", "R_INTERNATIONAL_MIG_2011"]
]
# States in alphabetical order
# census2010pop = 4/1/2010 resident Census 2010 population
# popestimate2010 = 7/1/2010 resident total population estimate
# npopchng2010 = Numeric Change in resident total population 4/1/2010 to 7/1/2010
# RINTERNATIONALMIG2011 = Net international migration rate in period 7/1/2010 to 6/30/2011
print(state_pop)
# Out:
# FIPS                                               CENSUS_2010_POP  \
# These data were posted to the ERS website (at h...
# 01000                                                    4,779,736
# 02000                                                      710,231
# 04000                                                    6,392,017
# 05000                                                    2,915,918
# 06000                                                   37,253,956
# 08000                                                    5,029,196
# 09000                                                    3,574,097
# 10000                                                      897,934
# 11000                                                      601,723
# 12000                                                   18,801,310
# 13000                                                    9,687,653
#
# FIPS                                               POP_ESTIMATE_2010  \
# These data were posted to the ERS website (at h...
# 01000                                                      4,785,448
# 02000                                                        713,906
# 04000                                                      6,407,774
# 05000                                                      2,921,978
# 06000                                                     37,320,903
# 08000                                                      5,048,281
# 09000                                                      3,579,125
# 10000                                                        899,595
# 11000                                                        605,085
# 12000                                                     18,845,785
# 13000                                                      9,711,810
#
# FIPS                                               N_POP_CHG_2010  \
# These data were posted to the ERS website (at h...
# 01000                                                       5,310
# 02000                                                       3,657
# 04000                                                      15,486
# 05000                                                       5,950
# 06000                                                      66,380
# 08000                                                      18,965
# 09000                                                       4,978
# 10000                                                       1,661
# 11000                                                       3,319
# 12000                                                      41,205
# 13000                                                      23,101
#
# FIPS                                               R_INTERNATIONAL_MIG_2011
# These data were posted to the ERS website (at h...
# 01000                                                                   1.0
# 02000                                                                   1.8
# 04000                                                                   2.7
# 05000                                                                   1.3
# 06000                                                                   2.8
# 08000                                                                   2.5
# 09000                                                                   3.6
# 10000                                                                   1.7
# 11000                                                                   4.0
# 12000                                                                   5.4
# 13000                                                                   1.2

# %%
# creating an array of 4/1/2010 resident Census 2010 population
pop = [4779736, 710231, 6392017, 2915918, 37253956, 5029196, 3574097, 897934, 601723, 18801310, 9687653]
x_axis = np.arange(len(pop))

# %%
# Tell matplotlib that we will be making a bar chart
# Users is our y axis and x_axis is, of course, our x axis
# We can apply align="edge" to ensure our bars line up with our tick marks
plt.bar(x_axis, pop, color='r', alpha=0.5, align="center")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 11 artists>

# %%
# Tell matplotlib where we would like to place each of our x axis headers
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, ["Alabama", "Alaska", "Arizona", "Arkansas", "California", "Colorada", "Conneticut", "Delaware", "District of COlumbia", "Florida", "Georgia"], rotation=90)
# Out:
# ([<matplotlib.axis.XTick at 0x17c86f63f28>,
#   <matplotlib.axis.XTick at 0x17c8d0a2e10>,
#   <matplotlib.axis.XTick at 0x17c8f9a74a8>,
#   <matplotlib.axis.XTick at 0x17c8f9a74e0>,
#   <matplotlib.axis.XTick at 0x17c911df518>,
#   <matplotlib.axis.XTick at 0x17c87cbd128>,
#   <matplotlib.axis.XTick at 0x17c87cbd9e8>,
#   <matplotlib.axis.XTick at 0x17c87cbdeb8>,
#   <matplotlib.axis.XTick at 0x17c8fa9ba90>,
#   <matplotlib.axis.XTick at 0x17c87efc278>,
#   <matplotlib.axis.XTick at 0x17c87efc588>],
#  <a list of 11 Text xticklabel objects>)

# %%
# Sets the x limits of the current chart
plt.xlim(-0.75, len(x_axis)-0.25)
# Out:
# (-0.75, 10.75)

# %%
# Sets the y limits of the current chart
plt.ylim(0, max(pop)+1000000)
# Out:
# (0, 38253956)

# %%
# Give our chart some labels and a tile
plt.title("First 13 States resident Census 2010 population")
plt.xlabel("States")
plt.ylabel("4/1/2010 resident Census 2010 population")
# Out:
# Text(53.402777777777786, 0.5, '4/1/2010 resident Census 2010 population')
