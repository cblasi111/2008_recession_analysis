# %%
# %matplotlib notebook
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, iplot
import seaborn as sns

# %%
# use init_notebook_mode to connect the Js to display the plots in the notebook
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# GDP DATA File to Load 
gdp_data_to_load = "Resources/GDP Per State.csv"

gdp_df = pd.read_csv(gdp_data_to_load)
gdp_df.dropna(inplace = True)

gdp_df.head()
# Out:
#     GeoFIPS          GeoName Region TableName  \
# 0   "00000"  United States *          SAGDP2N
# 1   "00000"  United States *          SAGDP2N
# 2   "00000"  United States *          SAGDP2N
# 3   "00000"  United States *          SAGDP2N
# 4   "00000"  United States *          SAGDP2N
#
#                            ComponentName                         Unit  \
# 0  Gross domestic product (GDP) by state  Millions of current dollars
# 1  Gross domestic product (GDP) by state  Millions of current dollars
# 2  Gross domestic product (GDP) by state  Millions of current dollars
# 3  Gross domestic product (GDP) by state  Millions of current dollars
# 4  Gross domestic product (GDP) by state  Millions of current dollars
#
#    IndustryId IndustryClassification  \
# 0         1.0                    ...
# 1         2.0                    ...
# 2         3.0                     11
# 3         4.0                111-112
# 4         5.0                113-115
#
# ...

# %%
#Grab state name and industries
state_name = [state for state in gdp_df["GeoName"]]
industry_list = [indsutry for indsutry in gdp_df["Description"]]
    
gdp_df
#gdp_complete.drop(["Far West", "Great Lakes", "Mideast", "New England", "Plains", 
                   #"Rocky Mountain", "Southeast", "Southwest"])
# Out:
#        GeoFIPS          GeoName Region TableName  \
# 0      "00000"  United States *          SAGDP2N
# 1      "00000"  United States *          SAGDP2N
# 2      "00000"  United States *          SAGDP2N
# 3      "00000"  United States *          SAGDP2N
# 4      "00000"  United States *          SAGDP2N
# 5      "00000"  United States *          SAGDP2N
# 6      "00000"  United States *          SAGDP2N
# 7      "00000"  United States *          SAGDP2N
# 8      "00000"  United States *          SAGDP2N
# 9      "00000"  United States *          SAGDP2N
# 10     "00000"  United States *          SAGDP2N
# 11     "00000"  United States *          SAGDP2N
# 12     "00000"  United States *          SAGDP2N
# 13     "00000"  United States *          SAGDP2N
# 14     "00000"  United States *          SAGDP2N
# 15     "00000"  United States *          SAGDP2N
# 16     "00000"  United States *          SAGDP2N
# 17     "00000"  United States *          SAGDP2N
# ...

# %%
# Converting 2007 GDP
convert_2007 = []

for gdp in gdp_df["2007"]:
    if gdp=="(L)":
        convert_2007.append(0)
    else:
        convert_2007.append(float(gdp))
        
    
gdp_df["new_2007"]=convert_2007

# Grouping by state and sum it by state
grouped_gdp_2007 = gdp_df.groupby(["GeoName"])["new_2007"].sum()
grouped_gdp_2007
# Out:
# GeoName
# Alabama                   871458.0
# Alaska                    258519.1
# Arizona                  1364345.5
# Arkansas                  505808.7
# California              10292533.3
# Colorado                 1290626.7
# Connecticut              1281368.7
# Delaware                  306022.7
# District of Columbia      441922.8
# Far West                14220540.1
# Florida                  4003435.1
# Georgia                  2157946.5
# Great Lakes             10973481.9
# Hawaii                    327330.8
# Idaho                     279017.2
# Illinois                 3454991.5
# Indiana                  1452643.8
# Iowa                      734984.2
# Kansas                    638964.7
# Kentucky                  807294.0
# Louisiana                1107719.4
# Maine                     256019.0
# Maryland                 1456079.2
# Massachusetts            2026627.1
# Michigan                 2153496.8
# Mideast                 13617117.0
# ...

# %%
# Converting 2008 GDP
convert_2008 = []

for gdp in gdp_df["2008"]:
    if gdp=="(L)":
        convert_2008.append(0)
    else:
        convert_2008.append(float(gdp))
        
    
gdp_df["new_2008"]=convert_2008

# Grouping by state and sum it by state
grouped_gdp_2008 = gdp_df.groupby(["GeoName"])["new_2008"].sum()
grouped_gdp_2008
# Out:
# GeoName
# Alabama                   887464.8
# Alaska                    292201.8
# Arizona                  1350187.0
# Arkansas                  516470.4
# California              10503609.1
# Colorado                 1341405.2
# Connecticut              1298767.5
# Delaware                  296140.3
# District of Columbia      467694.1
# Far West                14526292.8
# Florida                  3914140.1
# Georgia                  2151324.1
# Great Lakes             10893048.1
# Hawaii                    334810.0
# Idaho                     289238.6
# Illinois                 3438746.0
# Indiana                  1471431.9
# Iowa                      728294.7
# Kansas                    666768.6
# Kentucky                  822714.2
# Louisiana                1154393.0
# Maine                     260522.7
# Maryland                 1496701.5
# Massachusetts            2069449.0
# Michigan                 2046701.1
# Mideast                 13784135.0
# ...

# %%
# Converting 2009 GDP
convert_2009 = []

for gdp in gdp_df["2009"]:
    if gdp=="(L)":
        convert_2009.append(0)
    else:
        convert_2009.append(float(gdp))
        
    
gdp_df["new_2009"]=convert_2009

# Grouping by state and sum it by state
grouped_gdp_2009 = gdp_df.groupby(["GeoName"])["new_2009"].sum()
grouped_gdp_2009
# Out:
# GeoName
# Alabama                   859615.8
# Alaska                    259429.8
# Arizona                  1273380.6
# Arkansas                  503562.1
# California              10128368.6
# Colorado                 1302556.6
# Connecticut              1274555.1
# Delaware                  308894.0
# District of Columbia      468997.9
# Far West                14029901.7
# Florida                  3778413.3
# Georgia                  2119497.2
# Great Lakes             10615656.3
# Hawaii                    327742.1
# Idaho                     280023.3
# Illinois                 3436525.7
# Indiana                  1404028.5
# Iowa                      723108.2
# Kansas                    647334.3
# Kentucky                  809094.3
# Louisiana                1097860.9
# Maine                     263894.7
# Maryland                 1526908.5
# Massachusetts            2087282.7
# Michigan                 1928197.9
# Mideast                 14061876.2
# ...

# %%
# Converting 2010 GDP
convert_2010 = []

for gdp in gdp_df["2010"]:
    if gdp=="(L)":
        convert_2010.append(0)
    else:
        convert_2010.append(float(gdp))
        
    
gdp_df["new_2010"]=convert_2010

# Grouping by state and sum it by state
grouped_gdp_2010 = gdp_df.groupby(["GeoName"])["new_2010"].sum()
grouped_gdp_2010
# Out:
# GeoName
# Alabama                   895916.8
# Alaska                    278173.4
# Arizona                  1297726.9
# Arkansas                  528989.9
# California              10422062.7
# Colorado                 1340689.3
# Connecticut              1281031.3
# Delaware                  312160.3
# District of Columbia      491715.1
# Far West                14457093.8
# Florida                  3846828.4
# Georgia                  2170592.2
# Great Lakes             11081332.8
# Hawaii                    341460.6
# Idaho                     288961.1
# Illinois                 3531857.2
# Indiana                  1514921.6
# Iowa                      752844.0
# Kansas                    666862.2
# Kentucky                  856831.9
# Louisiana                1206018.3
# Maine                     270347.1
# Maryland                 1596710.1
# Massachusetts            2191920.1
# Michigan                 2047446.6
# Mideast                 14661613.9
# ...

# %%
# Converting 2011 GDP
convert_2011 = []

for gdp in gdp_df["2011"]:
    if gdp=="(L)":
        convert_2011.append(0)
    else:
        convert_2011.append(float(gdp))
        
    
gdp_df["new_2011"]=convert_2011

# Grouping by state and sum it by state
grouped_gdp_2011 = gdp_df.groupby(["GeoName"])["new_2011"].sum()
grouped_gdp_2011
# Out:
# GeoName
# Alabama                   933486.7
# Alaska                    296906.4
# Arizona                  1352543.2
# Arkansas                  554165.7
# California              10840295.9
# Colorado                 1393966.6
# Connecticut              1272897.5
# Delaware                  328651.2
# District of Columbia      511421.4
# Far West                15039693.2
# Florida                  3904019.0
# Georgia                  2242578.1
# Great Lakes             11581547.3
# Hawaii                    352978.4
# Idaho                     296990.0
# Illinois                 3680781.9
# Indiana                  1563143.6
# Iowa                      786303.8
# Kansas                    710639.9
# Kentucky                  888398.0
# Louisiana                1224212.5
# Maine                     272126.5
# Maryland                 1654636.3
# Massachusetts            2273435.0
# Michigan                 2134966.2
# Mideast                 15021601.2
# ...

# %%
# Converting 2012 GDP
convert_2012 = []

for gdp in gdp_df["2012"]:
    if gdp=="(L)":
        convert_2012.append(0)
    else:
        convert_2012.append(float(gdp))
        
    
gdp_df["new_2012"]=convert_2012

# Grouping by state and sum it by state
grouped_gdp_2012 = gdp_df.groupby(["GeoName"])["new_2012"].sum()
grouped_gdp_2012
# Out:
# GeoName
# Alabama                   962169.8
# Alaska                    304040.3
# Arizona                  1409909.7
# Arkansas                  567182.7
# California              11378199.2
# Colorado                 1443071.5
# Connecticut              1312606.5
# Delaware                  338130.9
# District of Columbia      526651.7
# Far West                15745405.7
# Florida                  4033347.0
# Georgia                  2326628.9
# Great Lakes             12053669.5
# Hawaii                    369797.1
# Idaho                     303124.7
# Illinois                 3868285.2
# Indiana                  1610084.8
# Iowa                      842596.8
# Kansas                    738897.4
# Kentucky                  923848.1
# Louisiana                1251292.5
# Maine                     278040.3
# Maryland                 1691144.8
# Massachusetts            2387291.5
# Michigan                 2235281.4
# Mideast                 15823565.7
# ...

# %%
# Converting 2013 GDP
convert_2013 = []

for gdp in gdp_df["2013"]:
    if gdp=="(L)":
        convert_2013.append(0)
    else:
        convert_2013.append(float(gdp))
        
    
gdp_df["new_2013"]=convert_2013

# Grouping by state and sum it by state
grouped_gdp_2013 = gdp_df.groupby(["GeoName"])["new_2013"].sum()
grouped_gdp_2013
# Out:
# GeoName
# Alabama                   991891.2
# Alaska                    298100.1
# Arizona                  1444997.3
# Arkansas                  598103.1
# California              11988756.8
# Colorado                 1521437.2
# Connecticut              1324429.7
# Delaware                  330299.9
# District of Columbia      537351.2
# Far West                16497931.5
# Florida                  4208492.4
# Georgia                  2419589.0
# Great Lakes             12442445.1
# Hawaii                    382035.4
# Idaho                     320108.1
# Illinois                 3960759.6
# Indiana                  1675575.4
# Iowa                      857559.0
# Kansas                    751011.8
# Kentucky                  957857.9
# Louisiana                1222291.3
# Maine                     282413.6
# Maryland                 1723719.5
# Massachusetts            2435914.5
# Michigan                 2311640.6
# Mideast                 16197139.3
# ...

# %%
# Converting 2014 GDP
convert_2014 = []

for gdp in gdp_df["2014"]:
    if gdp=="(L)":
        convert_2014.append(0)
    else:
        convert_2014.append(float(gdp))
        
    
gdp_df["new_2014"]=convert_2014

# Grouping by state and sum it by state
grouped_gdp_2014 = gdp_df.groupby(["GeoName"])["new_2014"].sum()
grouped_gdp_2014
# Out:
# GeoName
# Alabama                  1004377.2
# Alaska                    290090.0
# Arizona                  1496149.6
# Arkansas                  615173.9
# California              12706845.5
# Colorado                 1616678.7
# Connecticut              1333932.1
# Delaware                  368947.8
# District of Columbia      563427.3
# Far West                17415312.4
# Florida                  4415519.0
# Georgia                  2550492.3
# Great Lakes             13010583.2
# Hawaii                    392335.5
# Idaho                     334119.1
# Illinois                 4107371.0
# Indiana                  1763865.7
# Iowa                      920009.2
# Kansas                    778005.8
# Kentucky                  980816.2
# Louisiana                1273663.4
# Maine                     293681.4
# Maryland                 1781973.9
# Massachusetts            2540041.3
# Michigan                 2400879.7
# Mideast                 16951368.3
# ...

# %%
# Converting 2015 GDP
convert_2015 = []

for gdp in gdp_df["2015"]:
    if gdp=="(L)":
        convert_2015.append(0)
    else:
        convert_2015.append(float(gdp))
        
    
gdp_df["new_2015"]=convert_2015

# Grouping by state and sum it by state
grouped_gdp_2015 = gdp_df.groupby(["GeoName"])["new_2015"].sum()
grouped_gdp_2015
# Out:
# GeoName
# Alabama                  1038134.9
# Alaska                    259840.1
# Arizona                  1565713.8
# Arkansas                  620497.5
# California              13547062.5
# Colorado                 1674526.9
# Connecticut              1391691.1
# Delaware                  390441.0
# District of Columbia      589897.1
# Far West                18527750.0
# Florida                  4714514.7
# Georgia                  2694428.2
# Great Lakes             13466881.1
# Hawaii                    417834.4
# Idaho                     347204.4
# Illinois                 4253862.5
# Indiana                  1787215.4
# Iowa                      954442.6
# Kansas                    797835.9
# Kentucky                 1010344.9
# Louisiana                1248439.5
# Maine                     302080.9
# Maryland                 1857127.6
# Massachusetts            2700001.0
# Michigan                 2536638.2
# Mideast                 17620382.6
# ...

# %%
# Converting 2016 GDP
convert_2016 = []

for gdp in gdp_df["2016"]:
    if gdp=="(L)":
        convert_2016.append(0)
    else:
        convert_2016.append(float(gdp))
        
    
gdp_df["new_2016"]=convert_2016

# Grouping by state and sum it by state
grouped_gdp_2016 = gdp_df.groupby(["GeoName"])["new_2016"].sum()
grouped_gdp_2016
# Out:
# GeoName
# Alabama                  1051999.2
# Alaska                    252970.3
# Arizona                  1642651.5
# Arkansas                  627689.2
# California              14103819.0
# Colorado                 1730990.3
# Connecticut              1410048.4
# Delaware                  385591.1
# District of Columbia      611985.5
# Far West                19296977.2
# Florida                  4951845.6
# Georgia                  2831905.8
# Great Lakes             13769303.3
# Hawaii                    434234.0
# Idaho                     362680.7
# Illinois                 4326539.1
# Indiana                  1832318.1
# Iowa                      964461.0
# Kansas                    820722.8
# Kentucky                 1026739.5
# Louisiana                1208589.8
# Maine                     313077.4
# Maryland                 1949520.7
# Massachusetts            2794583.2
# Michigan                 2624278.7
# Mideast                 18171561.5
# ...

# %%
# Converting 2017 GDP
convert_2017 = []

for gdp in gdp_df["2017"]:
    if gdp=="(L)":
        convert_2017.append(0)
    else:
        convert_2017.append(float(gdp))
        
    
gdp_df["new_2017"]=convert_2017

# Grouping by state and sum it by state
grouped_gdp_2017 = gdp_df.groupby(["GeoName"])["new_2017"].sum()
grouped_gdp_2017
# Out:
# GeoName
# Alabama                   1097250.4
# Alaska                     266457.7
# Arizona                   1723649.8
# Arkansas                   647430.5
# California               14890926.2
# Colorado                  1828562.6
# Connecticut               1424163.8
# Delaware                   395426.2
# District of Columbia       637511.9
# Far West                 20356597.8
# Florida                   5170783.2
# Georgia                   2957809.6
# Great Lakes              14217369.0
# Hawaii                     452266.4
# Idaho                      378953.5
# Illinois                  4438639.7
# Indiana                   1903617.2
# Iowa                       979089.7
# Kansas                     844579.4
# Kentucky                  1059098.1
# Louisiana                 1265653.8
# Maine                      324534.4
# Maryland                  2025167.0
# Massachusetts             2909402.8
# Michigan                  2707273.3
# Mideast                  18849412.8
# ...

# %%
# Converting 2018 GDP
convert_2018 = []

for gdp in gdp_df["2018"]:
    if gdp=="(D)":
        convert_2018.append(0)
    elif gdp=="(NA)":
        convert_2018.append(0)
    else:
        convert_2018.append(float(gdp))
        
    
gdp_df["new_2018"]=convert_2018

# Grouping by state and sum it by state
grouped_gdp_2018 = gdp_df.groupby(["GeoName"])["new_2018"].sum()
grouped_gdp_2018
# Out:
# GeoName
# Alabama                   979230.9
# Alaska                    233290.3
# Arizona                  1570997.7
# Arkansas                  581071.5
# California              13368804.1
# Colorado                 1661732.6
# Connecticut              1260220.9
# Delaware                  348124.4
# District of Columbia      545554.1
# Far West                18327302.1
# Florida                  4716555.9
# Georgia                  2652465.2
# Great Lakes             12781191.0
# Hawaii                    396835.2
# Idaho                     346660.0
# Illinois                 3993353.3
# Indiana                  1705848.6
# Iowa                      869907.1
# Kansas                    754850.9
# Kentucky                  939421.9
# Louisiana                1151984.7
# Maine                     290353.6
# Maryland                 1774345.2
# Massachusetts            2605897.0
# Michigan                 2428536.2
# Mideast                 16123170.6
# ...

# %%
# Create a dataframe
gdp_totals = pd.DataFrame({"GDP 2007": grouped_gdp_2007,
                            "GDP 2008": grouped_gdp_2008,
                            "GDP 2009": grouped_gdp_2009,
                            "GDP 2010": grouped_gdp_2010,
                            "GDP 2011": grouped_gdp_2011,
                            "GDP 2012": grouped_gdp_2012,
                            "GDP 2013": grouped_gdp_2013,
                            "GDP 2014": grouped_gdp_2014,
                            "GDP 2015": grouped_gdp_2015,
                            "GDP 2016": grouped_gdp_2016,
                            "GDP 2017": grouped_gdp_2017,
                            "GDP 2018": grouped_gdp_2018})

# %%
# Calculate the delta from a year by year perspective for each state
delta_07_08 = ((gdp_totals["GDP 2008"] - gdp_totals["GDP 2007"])/ gdp_totals["GDP 2007"])*100
delta_08_09 = ((gdp_totals["GDP 2009"] - gdp_totals["GDP 2008"])/ gdp_totals["GDP 2008"])*100
delta_09_10 = ((gdp_totals["GDP 2010"] - gdp_totals["GDP 2009"])/ gdp_totals["GDP 2009"])*100
delta_10_11 = ((gdp_totals["GDP 2011"] - gdp_totals["GDP 2010"])/ gdp_totals["GDP 2010"])*100
delta_11_12 = ((gdp_totals["GDP 2012"] - gdp_totals["GDP 2011"])/ gdp_totals["GDP 2011"])*100
delta_12_13 = ((gdp_totals["GDP 2013"] - gdp_totals["GDP 2012"])/ gdp_totals["GDP 2012"])*100
delta_13_14 = ((gdp_totals["GDP 2014"] - gdp_totals["GDP 2013"])/ gdp_totals["GDP 2013"])*100
delta_14_15 = ((gdp_totals["GDP 2015"] - gdp_totals["GDP 2014"])/ gdp_totals["GDP 2014"])*100
delta_15_16 = ((gdp_totals["GDP 2016"] - gdp_totals["GDP 2015"])/ gdp_totals["GDP 2015"])*100
delta_16_17 = ((gdp_totals["GDP 2017"] - gdp_totals["GDP 2016"])/ gdp_totals["GDP 2016"])*100
delta_17_18 = ((gdp_totals["GDP 2018"] - gdp_totals["GDP 2017"])/ gdp_totals["GDP 2017"])*100
total_delta = ((gdp_totals["GDP 2018"] - gdp_totals["GDP 2007"])/ gdp_totals["GDP 2007"])*100

# %%
gdp_complete = pd.DataFrame({"GDP 2007": grouped_gdp_2007, 
                             "GDP 2008": grouped_gdp_2008, 
                             "GDP 2009": grouped_gdp_2009, 
                             "GDP 2010": grouped_gdp_2010, 
                             "GDP 2011": grouped_gdp_2011, 
                             "GDP 2012": grouped_gdp_2012, 
                             "GDP 2013": grouped_gdp_2013, 
                             "GDP 2014": grouped_gdp_2014, 
                             "GDP 2015": grouped_gdp_2015, 
                             "GDP 2016": grouped_gdp_2016, 
                             "GDP 2017": grouped_gdp_2017, 
                             "GDP 2018": grouped_gdp_2018, 
                             "07-08 Delta": delta_07_08, 
                             "08-09 Delta": delta_08_09, 
                             "09-10 Delta": delta_09_10, 
                             "10-11 Delta": delta_10_11, 
                             "11-12 Delta": delta_11_12, 
                             "12-13 Delta": delta_12_13, 
                             "13-14 Delta": delta_13_14, 
                             "14-15 Delta": delta_14_15, 
                             "15-16 Delta": delta_15_16, 
                             "16-17 Delta": delta_16_17, 
                             "17-18 Delta": delta_17_18, 
                             "Total Delta": total_delta})

gdp_complete = gdp_complete.reset_index()
gdp_complete.head(50)
# Out:
#                  GeoName    GDP 2007    GDP 2008    GDP 2009    GDP 2010  \
# 0                Alabama    871458.0    887464.8    859615.8    895916.8
# 1                 Alaska    258519.1    292201.8    259429.8    278173.4
# 2                Arizona   1364345.5   1350187.0   1273380.6   1297726.9
# 3               Arkansas    505808.7    516470.4    503562.1    528989.9
# 4             California  10292533.3  10503609.1  10128368.6  10422062.7
# 5               Colorado   1290626.7   1341405.2   1302556.6   1340689.3
# 6            Connecticut   1281368.7   1298767.5   1274555.1   1281031.3
# 7               Delaware    306022.7    296140.3    308894.0    312160.3
# 8   District of Columbia    441922.8    467694.1    468997.9    491715.1
# 9               Far West  14220540.1  14526292.8  14029901.7  14457093.8
# 10               Florida   4003435.1   3914140.1   3778413.3   3846828.4
# 11               Georgia   2157946.5   2151324.1   2119497.2   2170592.2
# ...

# %%
# Create dataframe to show 07-08 change and 08-18 change
gdp_change_07_08 = gdp_complete["09-10 Delta"]
gdp_change_10_11 = gdp_complete["10-11 Delta"]
gdp_change_16_17 = gdp_complete["16-17 Delta"]
gdp_change_08_18 = ((gdp_complete["GDP 2018"] - gdp_complete["GDP 2008"])/ gdp_complete["GDP 2008"])*100
state_name = [state for state in gdp_complete["GeoName"]]

state_initials = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "DoC","FL",
                  "GA","HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA","ME",
                  "MD","MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV","NH",
                  "NJ","NM", "NY", "NC", "ND", "OH", "OK", "OR","PA","RI",
                  "SC", "SD", "TN", "TX", "UT", "VT", "VA", "WA","WV","WI", "WY"]

gdp_for_visualization = pd.DataFrame({"State": state_name,
                                      #"Abbreviation": state_initials,
                                      "GDP Change (2007-2008)": gdp_change_07_08, 
                                      "GDP Change (2010-2011)": gdp_change_10_11,
                                      "GDP Change (2016-2017)": gdp_change_16_17,
                                      "GDP Change (2008-2018)": gdp_change_08_18})

gdp_for_visualization = gdp_for_visualization.set_index("State")
gdp_for_visualization = gdp_for_visualization.drop("Far West", axis=0)
gdp_for_visualization = gdp_for_visualization.drop("Great Lakes", axis=0)
gdp_for_visualization = gdp_for_visualization.drop("Mideast", axis=0)
gdp_for_visualization = gdp_for_visualization.drop("New England", axis=0)
gdp_for_visualization = gdp_for_visualization.drop("Plains", axis=0)
gdp_for_visualization = gdp_for_visualization.drop("Rocky Mountain", axis=0)
gdp_for_visualization = gdp_for_visualization.drop("Southeast", axis=0)
gdp_for_visualization = gdp_for_visualization.drop("Southwest", axis=0)
gdp_for_visualization = gdp_for_visualization.drop("United States *", axis=0)
gdp_for_visualization = gdp_for_visualization.reset_index()

gdp_for_visualization["Abbreviation"] = state_initials

gdp_for_visualization
# Out:
#                    State  GDP Change (2007-2008)  GDP Change (2010-2011)  \
# 0                Alabama                4.222933                4.193459
# 1                 Alaska                7.224922                6.734289
# 2                Arizona                1.911942                4.224024
# 3               Arkansas                5.049586                4.759221
# 4             California                2.899718                4.012960
# 5               Colorado                2.927527                3.973874
# 6            Connecticut                0.508115               -0.634942
# 7               Delaware                1.057418                5.282831
# 8   District of Columbia                4.843774                4.007666
# 9                Florida                1.810683                1.486695
# 10               Georgia                2.410713                3.316418
# 11                Hawaii                4.185761                3.373098
# ...

# %%
top_states_07_08 = gdp_for_visualization.sort_values(["GDP Change (2007-2008)"],ascending = False).head(5)
del top_states_07_08['GDP Change (2008-2018)']
del top_states_07_08['Abbreviation']
del top_states_07_08['GDP Change (2010-2011)']
del top_states_07_08['GDP Change (2016-2017)']

bottom_states_07_08 = gdp_for_visualization.sort_values(["GDP Change (2007-2008)"],ascending = True).head(5)
del bottom_states_07_08['GDP Change (2008-2018)']
del bottom_states_07_08['Abbreviation']
del bottom_states_07_08['GDP Change (2010-2011)']
del bottom_states_07_08['GDP Change (2016-2017)']

# %%
# create a data object with the dict() method

# colorscale = 'Earth' --> this is the color for the geographical map elements
# locations = gdp_for_visualization['Unnamed: 0'] --> this is the index for the states
# locationmode = 'USA-states' --> this will tell plotly we want the US
# z = gdp_for_visualization['GDP Change (2007-2008)'] --> numerical value for each state element
# text = gdp_for_visualization['state'] --> this is the categorical value for each element
# colorbar = ['title': '2010 Census Population'] --> title on the right

data = dict(type = 'choropleth',
           colorscale = 'YlOrRd',
           locations = gdp_for_visualization["Abbreviation"],
           locationmode = 'USA-states',
           z = gdp_for_visualization['GDP Change (2007-2008)'],
           text = gdp_for_visualization["State"],
           colorbar = {'title': 'Change in GDP'},
           marker = dict(line = dict(color = 'rgb(255, 255, 255)', width=2)))

# %%
# create a layout object with the dict() method

# scope arguemnts to the map of interest
# showlakes argument turns on display for lakes
# lakecolor adjusts color of lakes

layout = dict(title = 'Change in GDP from 2007 to 2008 (%)',
             geo = dict(scope = 'usa', showlakes=True, lakecolor='rgb(85,173,240)'))

# %%
# use the go.figure to set up the object that gets passed into iplot() method
choromap = go.Figure(data = [data], layout = layout)

# %%
# use iplot() method to generate the plot
print(top_states_07_08)
print(bottom_states_07_08)
iplot(choromap)
# Out:
#            State  GDP Change (2007-2008)
# 34  North Dakota               10.948377
# 18     Louisiana                9.851649
# 14       Indiana                7.898209
# 1         Alaska                7.224922
# 43         Texas                6.799134
#           State  GDP Change (2007-2008)
# 6   Connecticut                0.508115
# 7      Delaware                1.057418
# 9       Florida                1.810683
# 2       Arizona                1.911942
# 30   New Jersey                1.994385
# <div>
#
#
#             <div id="d360f09a-0837-4553-92a2-adbfc31f5048" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d360f09a-0837-4553-92a2-adbfc31f5048")) {
# ...

# %%
top_states_08_18 = gdp_for_visualization.sort_values(['GDP Change (2008-2018)'],ascending = False).head(5)
del top_states_08_18["GDP Change (2007-2008)"]
del top_states_08_18['Abbreviation']
del top_states_08_18['GDP Change (2010-2011)']
del top_states_08_18['GDP Change (2016-2017)']

bottom_states_08_18 = gdp_for_visualization.sort_values(['GDP Change (2008-2018)'],ascending = True).head(5)
del bottom_states_08_18["GDP Change (2007-2008)"]
del bottom_states_08_18['Abbreviation']
del bottom_states_08_18['GDP Change (2010-2011)']
del bottom_states_08_18['GDP Change (2016-2017)']

# %%
data2 = dict(type = 'choropleth',
           colorscale = 'YlOrRd',
           locations = gdp_for_visualization["Abbreviation"],
           locationmode = 'USA-states',
           z = gdp_for_visualization['GDP Change (2008-2018)'],
           text = gdp_for_visualization["State"],
           colorbar = {'title': 'Change in GDP'},
           marker = dict(line = dict(color = 'rgb(255, 255, 255)', width=2))) 

layout = dict(title = 'Change in GDP from 2007 to 2008 (%)',
             geo = dict(scope = 'usa', showlakes=True, lakecolor='rgb(85,173,240)'))

choromap2 = go.Figure(data = [data2], layout = layout)

print(top_states_08_18)
print(bottom_states_08_18)
iplot(choromap2)
# Out:
#            State  GDP Change (2008-2018)
# 34  North Dakota               49.009513
# 47    Washington               35.336947
# 44          Utah               32.171805
# 32      New York               31.124087
# 4     California               27.278195
#           State  GDP Change (2008-2018)
# 50      Wyoming              -29.770157
# 1        Alaska              -20.161238
# 6   Connecticut               -2.967937
# 18    Louisiana               -0.208620
# 31   New Mexico                0.110464
# <div>
#
#
#             <div id="4671187e-a0ed-4f5e-9028-0b37811744d9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("4671187e-a0ed-4f5e-9028-0b37811744d9")) {
# ...

# %%
# UNEMPLOYED DATA
economic_unemployed = "Resources/Unemployment and Median Income by state and year.csv"
economic_unemployed_df = pd.read_csv(economic_unemployed, delimiter =",", encoding="utf-8-sig", skiprows=7)

# %%
economic_data = economic_unemployed_df.rename(columns={"Unemployment_rate_2007":"Unemployment rate 2007",
                                               "Unemployment_rate_2008":"Unemployment rate 2008",
                                                "Unemployment_rate_2009":"Unemployment rate 2009", 
                                                "Unemployment_rate_2010":"Unemployment rate 2010",
                                               "Unemployment_rate_2011":"Unemployment rate 2011",
                                               "Unemployment_rate_2012":"Unemployment rate 2012",
                                               "Unemployment_rate_2013":"Unemployment rate 2013",
                                               "Unemployment_rate_2014":"Unemployment rate 2014",
                                               "Unemployment_rate_2015":"Unemployment rate 2015",
                                               "Unemployment_rate_2016":"Unemployment rate 2016",
                                               "Unemployment_rate_2017":"Unemployment rate 2017",
                                               "Unemployment_rate_2018":"Unemployment rate 2018"})

#data from 2007 to 2010
economic_unemployed_table = economic_data[["State", "Area_name", 'Unemployment rate 2007','Unemployment rate 2008','Unemployment rate 2009',"Unemployment rate 2010","Unemployment rate 2011","Unemployment rate 2012","Unemployment rate 2013","Unemployment rate 2014","Unemployment rate 2015","Unemployment rate 2016","Unemployment rate 2017","Unemployment rate 2018"]]
economic_unemployed_table
# Out:
#      State                    Area_name  Unemployment rate 2007  \
# 0       US                United States                     4.6
# 1       AL                      Alabama                     4.0
# 2       AL           Autauga County, AL                     3.3
# 3       AL           Baldwin County, AL                     3.1
# 4       AL           Barbour County, AL                     6.3
# 5       AL              Bibb County, AL                     4.1
# 6       AL            Blount County, AL                     3.2
# 7       AL           Bullock County, AL                     9.4
# 8       AL            Butler County, AL                     6.2
# 9       AL           Calhoun County, AL                     3.9
# 10      AL          Chambers County, AL                     6.5
# 11      AL          Cherokee County, AL                     4.2
# 12      AL           Chilton County, AL                     3.4
# 13      AL           Choctaw County, AL                     5.9
# ...

# %%
#Create Unemployed rate table per each state
economic_df=economic_unemployed_table
economic_df
#extract just states based off column name Area_name
economic_df_states = economic_df[~economic_df['Area_name'].str.contains(",")]

# %%
rate_07_08 = (economic_df_states["Unemployment rate 2008"] - economic_df_states["Unemployment rate 2007"])
rate_08_18 = (economic_df_states["Unemployment rate 2018"] - economic_df_states["Unemployment rate 2008"])
rate_08_17 = (economic_df_states["Unemployment rate 2017"] - economic_df_states["Unemployment rate 2008"])

# %%
state_table = pd.DataFrame({"Unemployment Rate Change from 2007 to 2008":rate_07_08, 
                            "Unemployment Rate Change from 2008 to 2018": rate_08_18,
                            "Unemployment Rate Change from 2008 to 2017": rate_08_17
                           })

# %%
economic_df_states["Rate Change from 2007 to 2008"]=state_table['Unemployment Rate Change from 2007 to 2008']
economic_df_states["Rate Change from 2008 to 2018"]=state_table['Unemployment Rate Change from 2008 to 2018']
economic_df_states["Rate Change from 2008 to 2017"]=state_table['Unemployment Rate Change from 2008 to 2017']
# Out:
# C:\Users\rayrt\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\rayrt\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\rayrt\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
economic_df_states
# Out:
#      State             Area_name  Unemployment rate 2007  \
# 0       US         United States                     4.6
# 1       AL               Alabama                     4.0
# 69      AK                Alaska                     6.3
# 102     AZ               Arizona                     3.9
# 118     AR              Arkansas                     5.3
# 194     CA            California                     5.4
# 253     Co              Colorado                     3.7
# 318     CT           Connecticut                     4.5
# 327     DE              Delaware                     3.4
# 331     DC  District of Columbia                     5.5
# 332     DC  District of Columbia                     5.5
# 333     FL               Florida                     4.0
# 401     GA               Georgia                     4.5
# 561     HI                Hawaii                     2.8
# 566     ID                 Idaho                     3.1
# ...

# %%
top_states_unemployed = economic_df_states.sort_values(['Rate Change from 2007 to 2008'],ascending = False).head(5)
del top_states_unemployed["Rate Change from 2008 to 2018"]
del top_states_unemployed["State"]
del top_states_unemployed["Unemployment rate 2007"]
del top_states_unemployed["Unemployment rate 2008"]
del top_states_unemployed["Unemployment rate 2009"]
del top_states_unemployed["Unemployment rate 2010"]
del top_states_unemployed["Unemployment rate 2011"]
del top_states_unemployed["Unemployment rate 2012"]
del top_states_unemployed["Unemployment rate 2013"]
del top_states_unemployed["Unemployment rate 2014"]
del top_states_unemployed["Unemployment rate 2015"]
del top_states_unemployed["Unemployment rate 2016"]
del top_states_unemployed["Unemployment rate 2017"]
del top_states_unemployed["Unemployment rate 2018"]



bottom_states_unemployed = economic_df_states.sort_values(['Rate Change from 2007 to 2008'],ascending = True).head(5)
del bottom_states_unemployed["Rate Change from 2008 to 2018"]
del bottom_states_unemployed["State"]
del bottom_states_unemployed["Unemployment rate 2007"]
del bottom_states_unemployed["Unemployment rate 2008"]
del bottom_states_unemployed["Unemployment rate 2009"]
del bottom_states_unemployed["Unemployment rate 2010"]
del bottom_states_unemployed["Unemployment rate 2011"]
del bottom_states_unemployed["Unemployment rate 2012"]
del bottom_states_unemployed["Unemployment rate 2013"]
del bottom_states_unemployed["Unemployment rate 2014"]
del bottom_states_unemployed["Unemployment rate 2015"]
del bottom_states_unemployed["Unemployment rate 2016"]
del bottom_states_unemployed["Unemployment rate 2017"]
del bottom_states_unemployed["Unemployment rate 2018"]

# %%
# create a data object with the dict() method

# colorscale = 'Earth' --> this is the color for the geographical map elements
# locations = pop_df['Unnamed: 0'] --> this is the index for the states
# locationmode = 'USA-states' --> this will tell plotly we want the US
# z = pop_df['census2010pop'] --> numerical value for each state element
# text = pop_df['state'] --> this is the categorical value for each element
# colorbar = ['title': '2010 Census Population'] --> title on the right
data = dict(type = 'choropleth',
          colorscale = 'YlOrRd',
          locations = economic_df_states['State'],
          locationmode = 'USA-states',
          z = economic_df_states['Rate Change from 2007 to 2008'],
          text = economic_df_states['Area_name'],
          colorbar = {'title': 'Δ% Rate Change from 2007 to 2008 (%)'},
          marker = dict(line = dict(color = 'rgb(255, 255, 255)', width=2)))

# %%
# create a layout object with the dict() method

# scope arguemnts to the map of interest
# showlakes argument turns on display for lakes
# lakecolor adjusts color of lakes

layout = dict(title = 'Δ% Rate Change from 2007 to 2008 (%)',
            geo = dict(scope = 'usa', showlakes=True, lakecolor='rgb(85,173,240)'))

# %%
# use the go.figure to set up the object that gets passed into iplot() method

choromap = go.Figure(data = [data], layout = layout)

# %%
# use iplot() method to generate the plot
print(top_states_unemployed)
print(bottom_states_unemployed)
iplot(choromap)
# Out:
#          Area_name  Rate Change from 2007 to 2008  \
# 2353  Rhode Island                            2.6
# 102        Arizona                            2.3
# 333        Florida                            2.3
# 1778        Nevada                            2.2
# 566          Idaho                            2.0
#
#       Rate Change from 2008 to 2017
# 2353                           -3.4
# 102                            -1.3
# 333                            -2.1
# 1778                           -1.6
# 566                            -1.9
#           Area_name  Rate Change from 2007 to 2008  \
# 2170       Oklahoma                           -0.4
# 3043  West Virginia                           -0.3
# 3099      Wisconsin                            0.0
# 2027   North Dakota                            0.1
# 118        Arkansas                            0.2
#
#       Rate Change from 2008 to 2017
# 2170                            0.5
# 3043                            0.9
# ...

# %%
top_states_unemployed = economic_df_states.sort_values(['Rate Change from 2008 to 2018'],ascending = False).head(5)
del top_states_unemployed["Rate Change from 2007 to 2008"]
del top_states_unemployed["State"]
del top_states_unemployed["Unemployment rate 2007"]
del top_states_unemployed["Unemployment rate 2008"]
del top_states_unemployed["Unemployment rate 2009"]
del top_states_unemployed["Unemployment rate 2010"]
del top_states_unemployed["Unemployment rate 2011"]
del top_states_unemployed["Unemployment rate 2012"]
del top_states_unemployed["Unemployment rate 2013"]
del top_states_unemployed["Unemployment rate 2014"]
del top_states_unemployed["Unemployment rate 2015"]
del top_states_unemployed["Unemployment rate 2016"]
del top_states_unemployed["Unemployment rate 2017"]
del top_states_unemployed["Unemployment rate 2018"]



bottom_states_unemployed = economic_df_states.sort_values(['Rate Change from 2008 to 2018'],ascending = True).head(5)
del bottom_states_unemployed["Rate Change from 2007 to 2008"]
del bottom_states_unemployed["State"]
del bottom_states_unemployed["Unemployment rate 2007"]
del bottom_states_unemployed["Unemployment rate 2008"]
del bottom_states_unemployed["Unemployment rate 2009"]
del bottom_states_unemployed["Unemployment rate 2010"]
del bottom_states_unemployed["Unemployment rate 2011"]
del bottom_states_unemployed["Unemployment rate 2012"]
del bottom_states_unemployed["Unemployment rate 2013"]
del bottom_states_unemployed["Unemployment rate 2014"]
del bottom_states_unemployed["Unemployment rate 2015"]
del bottom_states_unemployed["Unemployment rate 2016"]
del bottom_states_unemployed["Unemployment rate 2017"]
del bottom_states_unemployed["Unemployment rate 2018"]

# %%
# create a data object with the dict() method

# colorscale = 'Earth' --> this is the color for the geographical map elements
# locations = pop_df['Unnamed: 0'] --> this is the index for the states
# locationmode = 'USA-states' --> this will tell plotly we want the US
# z = pop_df['census2010pop'] --> numerical value for each state element
# text = pop_df['state'] --> this is the categorical value for each element
# colorbar = ['title': '2010 Census Population'] --> title on the right
data = dict(type = 'choropleth',
          colorscale = 'YlOrRd',
          locations = economic_df_states['State'],
          locationmode = 'USA-states',
          z = economic_df_states['Rate Change from 2008 to 2018'],
          text = economic_df_states['Area_name'],
          colorbar = {'title': 'Δ% Rate change from 2008 to 2018'},
          marker = dict(line = dict(color = 'rgb(255, 255, 255)', width=2)))

# %%
# create a layout object with the dict() method

# scope arguemnts to the map of interest
# showlakes argument turns on display for lakes
# lakecolor adjusts color of lakes

layout = dict(title = 'Δ% Rate change from Rate 2008 to 2018',
            geo = dict(scope = 'usa', showlakes=True, lakecolor='rgb(85,173,240)'))

# %%
# use the go.figure to set up the object that gets passed into iplot() method

choromap = go.Figure(data = [data], layout = layout)

# %%
# use iplot() method to generate the plot
print(top_states_unemployed)
print(bottom_states_unemployed)
iplot(choromap)
# Out:
#           Area_name  Rate Change from 2008 to 2018  \
# 3043  West Virginia                            1.0
# 3172        Wyoming                            1.0
# 1829     New Mexico                            0.4
# 1134      Louisiana                            0.0
# 2406   South Dakota                           -0.1
#
#       Rate Change from 2008 to 2017
# 3043                            0.9
# 3172                            1.1
# 1829                            1.4
# 1134                            0.2
# 2406                            0.1
#            Area_name  Rate Change from 2008 to 2018  \
# 1256        Michigan                           -3.9
# 2353    Rhode Island                           -3.7
# 2359  South Carolina                           -3.4
# 2473       Tennessee                           -3.1
# 194       California                           -3.1
#
#       Rate Change from 2008 to 2017
# 1256                           -3.4
# 2353                           -3.4
# ...

# %%
# POPULATION DATA
pop_file = "Resources/Population Estimates.csv"
pop_df = pd.read_csv(pop_file, skiprows=[0])
pop_df.head()
# Out:
#   These data were posted to the ERS website (at https://www.ers.usda.gov/data-products/county-level-data-sets/download-data.aspx) May 2019. Contact: Tim Parker, ERS/USDA, timothy.parker@usda.gov, (202) 694-5435.  \
# 0                                               FIPS
# 1                                              00000
# 2                                              01000
# 3                                              01001
# 4                                              01003
#
#   Unnamed: 1      Unnamed: 2                       Unnamed: 3  \
# 0      State       Area_Name  Rural-urban_Continuum Code_2003
# 1         US   United States                              NaN
# 2         AL         Alabama                              NaN
# 3         AL  Autauga County                                2
# 4         AL  Baldwin County                                4
#
#                         Unnamed: 4                 Unnamed: 5  \
# ...

# %%
new_header = pop_df.iloc[0]
pop_df = pop_df[1:]
pop_df.columns = new_header
pop_df.head(50)
# Out:
# 0    FIPS State          Area_Name Rural-urban_Continuum Code_2003  \
# 1   00000    US      United States                             NaN
# 2   01000    AL            Alabama                             NaN
# 3   01001    AL     Autauga County                               2
# 4   01003    AL     Baldwin County                               4
# 5   01005    AL     Barbour County                               6
# 6   01007    AL        Bibb County                               1
# 7   01009    AL      Blount County                               1
# 8   01011    AL     Bullock County                               6
# 9   01013    AL      Butler County                               6
# 10  01015    AL     Calhoun County                               3
# 11  01017    AL    Chambers County                               6
# 12  01019    AL    Cherokee County                               8
# 13  01021    AL     Chilton County                               1
# ...

# %%
#pop_df = pop_df.set_index("FIPS")
#pop_df.head

# %%
pop_df = pop_df.drop_duplicates(subset='State', keep='first', inplace=False)
pop_df.head(50)
# Out:
# 0      FIPS State             Area_Name Rural-urban_Continuum Code_2003  \
# 1     00000    US         United States                             NaN
# 2     01000    AL               Alabama                             NaN
# 70    02000    AK                Alaska                             NaN
# 100   04000    AZ               Arizona                             NaN
# 116   05000    AR              Arkansas                             NaN
# 192   06000    CA            California                             NaN
# 251   08000    CO              Colorado                             NaN
# 316   09000    CT           Connecticut                             NaN
# 325   10000    DE              Delaware                             NaN
# 329   11000    DC  District of Columbia                             NaN
# 331   12000    FL               Florida                             NaN
# 399   13000    GA               Georgia                             NaN
# ...

# %%
pop_df = pop_df.drop(["Rural-urban_Continuum Code_2003", "Rural-urban_Continuum Code_2013", "Urban_Influence_Code_2003", "Urban_Influence_Code_2013", "Economic_typology_2015"], axis=1)
pop_df.head(55)
# Out:
# 0      FIPS State             Area_Name CENSUS_2010_POP ESTIMATES_BASE_2010  \
# 1     00000    US         United States     308,745,538         308,758,105
# 2     01000    AL               Alabama       4,779,736           4,780,138
# 70    02000    AK                Alaska         710,231             710,249
# 100   04000    AZ               Arizona       6,392,017           6,392,288
# 116   05000    AR              Arkansas       2,915,918           2,916,028
# 192   06000    CA            California      37,253,956          37,254,523
# 251   08000    CO              Colorado       5,029,196           5,029,316
# 316   09000    CT           Connecticut       3,574,097           3,574,147
# 325   10000    DE              Delaware         897,934             897,934
# 329   11000    DC  District of Columbia         601,723             601,766
# 331   12000    FL               Florida      18,801,310          18,804,580
# ...

# %%
pop_df_clean = pop_df.drop([1, 3274])
pop_df_clean.head(55)
# Out:
# 0      FIPS State             Area_Name CENSUS_2010_POP ESTIMATES_BASE_2010  \
# 2     01000    AL               Alabama       4,779,736           4,780,138
# 70    02000    AK                Alaska         710,231             710,249
# 100   04000    AZ               Arizona       6,392,017           6,392,288
# 116   05000    AR              Arkansas       2,915,918           2,916,028
# 192   06000    CA            California      37,253,956          37,254,523
# 251   08000    CO              Colorado       5,029,196           5,029,316
# 316   09000    CT           Connecticut       3,574,097           3,574,147
# 325   10000    DE              Delaware         897,934             897,934
# 329   11000    DC  District of Columbia         601,723             601,766
# 331   12000    FL               Florida      18,801,310          18,804,580
# 399   13000    GA               Georgia       9,687,653           9,688,709
# ...

# %%
# create a data object with the dict() method

# colorscale = 'Earth' --> this is the color for the geographical map elements
# locations = pop_df['Unnamed: 0'] --> this is the index for the states
# locationmode = 'USA-states' --> this will tell plotly we want the US
# z = pop_df['census2010pop'] --> numerical value for each state element
# text = pop_df['state'] --> this is the categorical value for each element
# colorbar = ['title': '2010 Census Population'] --> title on the right

data = dict(type = 'choropleth',
           colorscale = 'Jet',
           locations = pop_df_clean['State'],
           locationmode = 'USA-states',
           z = pop_df_clean['R_DOMESTIC_MIG_2011'],
           text = pop_df_clean['Area_Name'],
           colorbar = {'title': 'Migration Rate'},
           marker = dict(line = dict(color = 'rgb(255, 255, 255)', width=2)))

# %%
# create a layout object with the dict() method

# scope arguemnts to the map of interest
# showlakes argument turns on display for lakes
# lakecolor adjusts color of lakes

layout = dict(title = 'Net Domestic Migration Rate 2010-2011',
             geo = dict(scope = 'usa', showlakes=True, lakecolor='rgb(85,173,240)'))

# %%
# use the go.figure to set up the object that gets passed into iplot() method

choromap = go.Figure(data = [data], layout = layout)

# %%
# use iplot() method to generate the plot

iplot(choromap)
# Out:
# <div>
#
#
#             <div id="e1dd335a-dbe4-4bff-ab15-60df1b379bd1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("e1dd335a-dbe4-4bff-ab15-60df1b379bd1")) {
#                     Plotly.newPlot(
#                         'e1dd335a-dbe4-4bff-ab15-60df1b379bd1',
# ...

# %%
# create a data object with the dict() method

# colorscale = 'Earth' --> this is the color for the geographical map elements
# locations = pop_df['Unnamed: 0'] --> this is the index for the states
# locationmode = 'USA-states' --> this will tell plotly we want the US
# z = pop_df['census2010pop'] --> numerical value for each state element
# text = pop_df['state'] --> this is the categorical value for each element
# colorbar = ['title': '2010 Census Population'] --> title on the right

data = dict(type = 'choropleth',
           colorscale = 'Jet',
           locations = pop_df_clean['State'],
           locationmode = 'USA-states',
           z = pop_df_clean['R_DOMESTIC_MIG_2018'],
           text = pop_df_clean['Area_Name'],
           colorbar = {'title': 'Migration Rate'},
           marker = dict(line = dict(color = 'rgb(255, 255, 255)', width=2)))

# %%
# create a layout object with the dict() method

# scope arguemnts to the map of interest
# showlakes argument turns on display for lakes
# lakecolor adjusts color of lakes

layout = dict(title = 'Net Domestic Migration Rate 2017-2018',
             geo = dict(scope = 'usa', showlakes=True, lakecolor='rgb(85,173,240)'))

# %%
# use the go.figure to set up the object that gets passed into iplot() method

choromap = go.Figure(data = [data], layout = layout)

# %%
# use iplot() method to generate the plot
iplot(choromap)
# Out:
# <div>
#
#
#             <div id="ebf52fa6-b9df-4a1f-aae3-f4e476232ccb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ebf52fa6-b9df-4a1f-aae3-f4e476232ccb")) {
#                     Plotly.newPlot(
#                         'ebf52fa6-b9df-4a1f-aae3-f4e476232ccb',
# ...

# %%
economic_df_clean = economic_df_states.drop([0, 331])
economic_df_clean.head()
# Out:
#     State   Area_name  Unemployment rate 2007  Unemployment rate 2008  \
# 1      AL     Alabama                     4.0                     5.7
# 69     AK      Alaska                     6.3                     6.7
# 102    AZ     Arizona                     3.9                     6.2
# 118    AR    Arkansas                     5.3                     5.5
# 194    CA  California                     5.4                     7.3
#
#      Unemployment rate 2009  Unemployment rate 2010  Unemployment rate 2011  \
# 1                      11.0                    10.5                     9.6
# 69                      7.7                     7.9                     7.6
# 102                     9.9                    10.4                     9.5
# 118                     7.8                     8.2                     8.3
# 194                    11.2                    12.2                    11.7
#
#      Unemployment rate 2012  Unemployment rate 2013  Unemployment rate 2014  \
# ...

# %%
len(pop_df_clean)
# Out:
# 52

# %%
# Converting population 10-11
convert_10_11_pop = []

for pop in pop_df_clean["R_DOMESTIC_MIG_2011"]:
       convert_10_11_pop.append(float(pop))

pop_df_clean["Converted Population 10-11"]=convert_10_11_pop

# %%
# Scatter plot showing the relationship between GDP and Migration rates
pop_10_11 = pop_df_clean["Converted Population 10-11"]
unemployment_10_11 = economic_df_clean["Unemployment rate 2011"]
x_axis = np.arange(0,20,1)

plt.scatter(pop_10_11, unemployment_10_11, marker="o",
           facecolors="red", edgecolors="black", alpha=0.75)

plt.ylim(min(unemployment_10_11)-1, max(unemployment_10_11)+1)
plt.xlim(min(pop_10_11)-1, max(pop_10_11)+1)

plt.title("Unemployment vs. Domestic Migration Rate (2010-2011)")
plt.xlabel("Unemployment Rate")
plt.ylabel("Migration Rate")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
# Converting population 17-18
convert_17_18_pop = []

for pop in pop_df_clean["R_DOMESTIC_MIG_2018"]:
       convert_17_18_pop.append(float(pop))

pop_df_clean["Converted Population 17-18"]=convert_17_18_pop

# %%
# Scatter plot showing the relationship between GDP and Migration rates
# %matplotlib notebook
pop_17_18 = pop_df_clean["Converted Population 17-18"]
unemployment_17_18 = economic_df_clean["Unemployment rate 2018"]
x_axis = np.arange(0,20,1)

plt.scatter(pop_17_18, unemployment_17_18, marker="o",
           facecolors="red", edgecolors="black", alpha=0.75)

plt.ylim(min(unemployment_17_18)-1, max(unemployment_17_18)+1)
plt.xlim(min(pop_17_18)-1, max(pop_17_18)+1)

plt.title("Unemployment vs. Domestic Migration Rate (2017-2018)")
plt.xlabel("Unemployment Rate")
plt.ylabel("Migration Rate")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
# Poverty data
poverty2 = "Resources/hstpov21.csv"
poverty2_pd = pd.read_csv(poverty2, skiprows=4)
poverty2_df = pd.DataFrame(poverty2_pd)
poverty2_df.head()
# Out:
#         STATE   Total Number Standard\nerror Percent Standard\nerror.1
# 0     Alabama   4,806    723              49    15.0               1.0
# 1      Alaska     717    103              14    14.4               1.9
# 2     Arizona   6,990    926             107    13.2               1.5
# 3    Arkansas   2,924    432              28    14.8               0.9
# 4  California  39,237  4,872             187    12.4               0.5

# %%
pov2017 = poverty2_df.loc[0:50, :]
#pov2017["STATE"] = pov2017["STATE"].replace("District of Columbia", "D.C.")
#pov2017_reset =pov2017.reset_index()
pov2017_renamed =pov2017[["STATE","Total","Number","Percent"]]
pov2017_renamed_col = pov2017_renamed.rename(columns={"Total": "Total_Un_2017", 
                                                                 "Number": "Number_Un_2017", 
                                                                 "Percent": "Percent_Un_2017"})
print(pov2017_renamed_col) #D.C.

pov2008 = poverty2_df.loc[530:580, :]
pov2008_reset =pov2008.reset_index()
pov2008_reset_renamed =pov2008_reset[["STATE","Total","Number","Percent"]]
pov2008_reset_renamed_col = pov2008_reset_renamed.rename(columns={"Total": "Total_Un_2008", 
                                                                  "Number": "Number_Un_2008", 
                                                                  "Percent": "Percent_Un_2008"})
#print(pov2008_reset_renamed_col)  #D.C.

pov2007 = poverty2_df.loc[583:633, :]
pov2007_reset =pov2007.reset_index()
pov2007_reset_renamed =pov2007_reset[["STATE","Total","Number","Percent"]]
pov2007_reset_renamed_col = pov2007_reset_renamed.rename(columns={"Total": "Total_Un_2007", 
                                                                 "Number": "Number_Un_2007", 
                                                                 "Percent": "Percent_Un_2007"})
        
#print(pov2007_reset_renamed_col)  #D.C.
# Out:
#                    STATE Total_Un_2017 Number_Un_2017 Percent_Un_2017
# 0                Alabama         4,806            723            15.0
# 1                 Alaska           717            103            14.4
# 2                Arizona         6,990            926            13.2
# 3               Arkansas         2,924            432            14.8
# 4             California        39,237          4,872            12.4
# 5               Colorado         5,527            427             7.7
# 6            Connecticut         3,555            388            10.9
# 7               Delaware           967             89             9.2
# 8   District of Columbia           692             94            13.6
# 9                Florida        20,894          2,864            13.7
# 10               Georgia        10,227          1,356            13.3
# 11                Hawaii         1,402            144            10.3
# ...

# %%
merge_table = pd.merge(pov2007_reset_renamed_col, pov2008_reset_renamed_col, on="STATE", how="outer")  #merged 2007 and 2008 data
#print(merge_table)
merge_table2 = pd.merge(merge_table, pov2017_renamed_col, on="STATE", how="inner")  #merged previous table with 2017 data
print(merge_table2)  #note D.C. was removed
# Out:
#              STATE Total_Un_2007 Number_Un_2007 Percent_Un_2007 Total_Un_2008  \
# 0          Alabama         4,566            662            14.5         4,716
# 1           Alaska           675             51             7.6           672
# 2          Arizona         6,365            912            14.3         6,529
# 3         Arkansas         2,803            387            13.8         2,822
# 4       California        36,247          4,589            12.7        36,637
# 5         Colorado         4,872            478             9.8         4,908
# 6      Connecticut         3,471            309             8.9         3,433
# 7         Delaware           861             80             9.3           861
# 8          Florida        18,044          2,250            12.5        18,022
# 9          Georgia         9,486          1,294            13.6         9,541
# 10          Hawaii         1,264             94             7.5         1,255
# ...

# %%
##changes Percent_2007 to float
convert_2007 = []

for x in merge_table2["Percent_Un_2007"]:
    convert_2007.append(float(x))

merge_table2["New percent 2007"] = convert_2007
#print(merge_table2)
merge_table2.dtypes
# Out:
# STATE                object
# Total_Un_2007        object
# Number_Un_2007       object
# Percent_Un_2007      object
# Total_Un_2008        object
# Number_Un_2008       object
# Percent_Un_2008      object
# Total_Un_2017        object
# Number_Un_2017       object
# Percent_Un_2017      object
# New percent 2007    float64
# dtype: object

# %%
##changes Percent_2008 to float
convert_2008 = []

for x in merge_table2["Percent_Un_2008"]:
    convert_2008.append(float(x))

merge_table2["New percent 2008"] = convert_2008
print(merge_table2)
# Out:
#              STATE Total_Un_2007 Number_Un_2007 Percent_Un_2007 Total_Un_2008  \
# 0          Alabama         4,566            662            14.5         4,716
# 1           Alaska           675             51             7.6           672
# 2          Arizona         6,365            912            14.3         6,529
# 3         Arkansas         2,803            387            13.8         2,822
# 4       California        36,247          4,589            12.7        36,637
# 5         Colorado         4,872            478             9.8         4,908
# 6      Connecticut         3,471            309             8.9         3,433
# 7         Delaware           861             80             9.3           861
# 8          Florida        18,044          2,250            12.5        18,022
# 9          Georgia         9,486          1,294            13.6         9,541
# 10          Hawaii         1,264             94             7.5         1,255
# ...

# %%
##changes Percent_2017 to float
convert_2017 = []

for x in merge_table2["Percent_Un_2017"]:
    convert_2017.append(float(x))

merge_table2["New percent 2017"] = convert_2017
print(merge_table2)
#merge_table2.dtypes  #New percent 2007, 2008, 2017 are all floats now. rest are objects
# Out:
#              STATE Total_Un_2007 Number_Un_2007 Percent_Un_2007 Total_Un_2008  \
# 0          Alabama         4,566            662            14.5         4,716
# 1           Alaska           675             51             7.6           672
# 2          Arizona         6,365            912            14.3         6,529
# 3         Arkansas         2,803            387            13.8         2,822
# 4       California        36,247          4,589            12.7        36,637
# 5         Colorado         4,872            478             9.8         4,908
# 6      Connecticut         3,471            309             8.9         3,433
# 7         Delaware           861             80             9.3           861
# 8          Florida        18,044          2,250            12.5        18,022
# 9          Georgia         9,486          1,294            13.6         9,541
# 10          Hawaii         1,264             94             7.5         1,255
# ...

# %%
#table for visualization
table_vis = merge_table2[['STATE', 'Total_Un_2007', 'Number_Un_2007', 'New percent 2007', 'Total_Un_2008',
       'Number_Un_2008', 'New percent 2008', 'Total_Un_2017', 'Number_Un_2017', 'New percent 2017']]
table_vis
# Out:
#              STATE Total_Un_2007 Number_Un_2007  New percent 2007  \
# 0          Alabama         4,566            662              14.5
# 1           Alaska           675             51               7.6
# 2          Arizona         6,365            912              14.3
# 3         Arkansas         2,803            387              13.8
# 4       California        36,247          4,589              12.7
# 5         Colorado         4,872            478               9.8
# 6      Connecticut         3,471            309               8.9
# 7         Delaware           861             80               9.3
# 8          Florida        18,044          2,250              12.5
# 9          Georgia         9,486          1,294              13.6
# 10          Hawaii         1,264             94               7.5
# 11           Idaho         1,501            149               9.9
# 12        Illinois        12,680          1,262              10.0
# ...

# %%
delta_07_08 = table_vis["New percent 2008"] - table_vis["New percent 2007"]
delta_07_08
merge_table2["Change in Percent from 2007 to 2008"] = delta_07_08
merge_table2
# Out:
#              STATE Total_Un_2007 Number_Un_2007 Percent_Un_2007 Total_Un_2008  \
# 0          Alabama         4,566            662            14.5         4,716
# 1           Alaska           675             51             7.6           672
# 2          Arizona         6,365            912            14.3         6,529
# 3         Arkansas         2,803            387            13.8         2,822
# 4       California        36,247          4,589            12.7        36,637
# 5         Colorado         4,872            478             9.8         4,908
# 6      Connecticut         3,471            309             8.9         3,433
# 7         Delaware           861             80             9.3           861
# 8          Florida        18,044          2,250            12.5        18,022
# 9          Georgia         9,486          1,294            13.6         9,541
# 10          Hawaii         1,264             94             7.5         1,255
# ...

# %%
delta_08_17 = table_vis["New percent 2017"] - table_vis["New percent 2008"]
delta_08_17
merge_table2["Change in Percent from 2008 to 2017"] = delta_08_17
merge_table2
# Out:
#              STATE Total_Un_2007 Number_Un_2007 Percent_Un_2007 Total_Un_2008  \
# 0          Alabama         4,566            662            14.5         4,716
# 1           Alaska           675             51             7.6           672
# 2          Arizona         6,365            912            14.3         6,529
# 3         Arkansas         2,803            387            13.8         2,822
# 4       California        36,247          4,589            12.7        36,637
# 5         Colorado         4,872            478             9.8         4,908
# 6      Connecticut         3,471            309             8.9         3,433
# 7         Delaware           861             80             9.3           861
# 8          Florida        18,044          2,250            12.5        18,022
# 9          Georgia         9,486          1,294            13.6         9,541
# 10          Hawaii         1,264             94             7.5         1,255
# ...

# %%
poverty_changes_for_vis = merge_table2[["STATE", "Change in Percent from 2007 to 2008","Change in Percent from 2008 to 2017"]]
poverty_changes_for_vis.head()
# Out:
#         STATE  Change in Percent from 2007 to 2008  \
# 0     Alabama                                 -0.2
# 1      Alaska                                  0.6
# 2     Arizona                                  3.7
# 3    Arkansas                                  1.5
# 4  California                                  1.9
#
#    Change in Percent from 2008 to 2017
# 0                                  0.7
# 1                                  6.2
# 2                                 -4.8
# 3                                 -0.5
# 4                                 -2.2

# %%
state_initials = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE","FL",
                 "GA","HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA","ME",
                 "MD","MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV","NH",
                 "NJ","NM", "NY", "NC", "ND", "OH", "OK", "OR","PA","RI",
                 "SC", "SD", "TN", "TX", "UT", "VT", "VA", "WA","WV","WI", "WY"]

# %%
poverty_changes_for_vis["Abbreviations"] = state_initials
poverty_changes_for_vis
# Out:
# C:\Users\rayrt\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#              STATE  Change in Percent from 2007 to 2008  \
# 0          Alabama                                 -0.2
# 1           Alaska                                  0.6
# 2          Arizona                                  3.7
# 3         Arkansas                                  1.5
# 4       California                                  1.9
# 5         Colorado                                  1.2
# 6      Connecticut                                 -0.8
# 7         Delaware                                  0.3
# 8          Florida                                  0.6
# 9          Georgia                                  1.9
# ...

# %%
# create a data object with the dict() method

# colorscale = 'Earth' --> this is the color for the geographical map elements
# locations = pop_df['Unnamed: 0'] --> this is the index for the states
# locationmode = 'USA-states' --> this will tell plotly we want the US
# z = pop_df['census2010pop'] --> numerical value for each state element
# text = pop_df['state'] --> this is the categorical value for each element
# colorbar = ['title': '2010 Census Population'] --> title on the right

data = dict(type = 'choropleth',
          colorscale = 'Earth',
          locations = poverty_changes_for_vis['Abbreviations'],  #abbreviations
          locationmode = 'USA-states',
          z = poverty_changes_for_vis['Change in Percent from 2008 to 2017'],
          text = poverty_changes_for_vis['STATE'],
          colorbar = {'title': 'Change in % Poverty'},
          marker = dict(line = dict(color = 'rgb(255, 255, 255)', width=2)))

# create a layout object with the dict() method

# scope arguemnts to the map of interest
# showlakes argument turns on display for lakes
# lakecolor adjusts color of lakes

layout = dict(title = 'Change in Poverty Percentage from 2008 to 2017',
            geo = dict(scope = 'usa', showlakes=True, lakecolor='rgb(85,173,240)'))
# use the go.figure to set up the object that gets passed into iplot() method

choromap = go.Figure(data = [data], layout = layout)
# use iplot() method to generate the plot

iplot(choromap)
# Out:
# <div>
#
#
#             <div id="bea8f108-bea4-421f-95f4-8172735d8bfd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("bea8f108-bea4-421f-95f4-8172735d8bfd")) {
#                     Plotly.newPlot(
#                         'bea8f108-bea4-421f-95f4-8172735d8bfd',
# ...

# %%
data = dict(type = 'choropleth',
          colorscale = 'Earth',
          locations = poverty_changes_for_vis['Abbreviations'],  #abbreviations
          locationmode = 'USA-states',
          z = poverty_changes_for_vis['Change in Percent from 2007 to 2008'],
          text = poverty_changes_for_vis['STATE'],
          colorbar = {'title': 'Change in % Poverty'},
          marker = dict(line = dict(color = 'rgb(255, 255, 255)', width=2)))

# create a layout object with the dict() method

# scope arguemnts to the map of interest
# showlakes argument turns on display for lakes
# lakecolor adjusts color of lakes

layout = dict(title = 'Change in Poverty Percentage from 2007 to 2008',
            geo = dict(scope = 'usa', showlakes=True, lakecolor='rgb(85,173,240)'))
# use the go.figure to set up the object that gets passed into iplot() method

choromap = go.Figure(data = [data], layout = layout)
# use iplot() method to generate the plot

iplot(choromap)
# Out:
# <div>
#
#
#             <div id="f5723d14-0f5f-476d-beba-a15fe709612e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("f5723d14-0f5f-476d-beba-a15fe709612e")) {
#                     Plotly.newPlot(
#                         'f5723d14-0f5f-476d-beba-a15fe709612e',
# ...

# %%
# %matplotlib notebook
# Scatter plot showing the relationship between GDP and Poverty (2007-2008)
gdp_for_visualization2 = gdp_for_visualization.drop(gdp_for_visualization.index[8])
gdp_for_visualization2  #dropped DC from Charlie's data

gdp_07_08 = gdp_for_visualization2["GDP Change (2007-2008)"]
pov_07_08 = poverty_changes_for_vis["Change in Percent from 2007 to 2008"]
topGDPincreasestates = gdp_07_08


plt.scatter(gdp_07_08, pov_07_08, marker="o", facecolors="red", edgecolors="black", alpha=0.75)  #
#plt.plot()


plt.xlim(0, 12)
plt.ylim(-6, 8)


plt.title("2007-2008: % Change in GDP vs. Change in Poverty %")
plt.xlabel("% Change in GDP")
plt.ylabel("Change in Poverty %")
#matplotlib.pyplot.grid(which='major', axis='both')
plt.grid(True)    
from scipy.stats import linregress
(slope, intercept, _, _, _) = linregress(gdp_07_08, pov_07_08)
fit = slope * gdp_07_08 + intercept
fig, ax = plt.subplots()  #
ax.plot(gdp_07_08, pov_07_08, linewidth=0, marker='o', color="red")
ax.plot(gdp_07_08, fit, 'b--', linewidth=1, color="blue")
plt.grid(True)
plt.xlim(0, 12)
plt.ylim(-6, 8)
plt.title("2007-2008: % Change in GDP vs. Change in Poverty %")
plt.xlabel("% Change in GDP")
plt.ylabel("Change in Poverty %")
#color='green', marker='o', linestyle='dashed',
#...      linewidth=2, markersize=12)
#plt.show()
#plt.savefig("07_08_pov_gdp.png")
#plt.legend(loc="best") 
#x = gdp_07_08
#y = pov_07_08
#regression = pd.ols(y=y, x=x)
#regression.summary
#x = 
#y = 

import statsmodels.api as sm
import numpy as np
import matplotlib.pyplot as plt

X = gdp_07_08
Y = pov_07_08

results = sm.OLS(Y,sm.add_constant(X)).fit()

print (results.summary())

plt.scatter(X,Y)

X_plot = np.linspace(0,1,100)
plt.plot(X_plot, X_plot*results.params[0] + results.params[1])

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">
# <img src="data:image/png;base64,..." width="638.888905813665">
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-88-28053c91becb> in <module>
#      53 Y = pov_07_08
#      54
# ---> 55 results = sm.OLS(Y,sm.add_constant(X)).fit()
#      56
#      57 print (results.summary())
#
# ~\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     815                  **kwargs):
#     816         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 817                                   hasconst=hasconst, **kwargs)
#     818         if "weights" in self._init_keys:
#     819             self._init_keys.remove("weights")
#
# ...

# %%
# %matplotlib notebook
# Scatter plot showing the relationship between GDP and Poverty (2008-2017)
gdp_for_visualization2 = gdp_for_visualization.drop(gdp_for_visualization.index[8])
gdp_for_visualization2  #dropped DC from Charlie's data

gdp_08_17 = gdp_for_visualization2["GDP Change (2008-2017)"]
pov_08_17 = poverty_changes_for_vis["Change in Percent from 2008 to 2017"]
#topGDPincreasestates = gdp_07_08


plt.scatter(gdp_08_17, pov_08_17, marker="o", facecolors="red", edgecolors="black", alpha=0.75)  #

#plt.scatter(gdp_07_08[, pov_07_08, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)

#plt.xlim(0, 12)
plt.ylim(-6, 8)


plt.title("2008-2017: % Change in GDP vs. Change in Poverty %")
plt.xlabel("% Change in GDP")
plt.ylabel("Change in Poverty %")
#matplotlib.pyplot.grid(which='major', axis='both')
plt.grid(True)   
plt.savefig("08_17_pov_gdp.png")
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'GDP Change (2008-2017)'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-89-c1d32766b1db> in <module>
# ...

# %%
# %matplotlib notebook
# Scatter plot showing the relationship between %unemployment and Poverty (2007-2008)
economic_df_states2 = economic_df_states.drop([0, 331, 332, 3196]) #drop DCs, US, and Puerto Rico
#print(economic_df_states2)
#gdp_for_visualization2 = gdp_for_visualization.drop(gdp_for_visualization.index[8])
#gdp_for_visualization2  #dropped DC from Charlie's data

unemploy_07_08 = economic_df_states2["Rate Change from 2007 to 2008"]
pov_07_08 = poverty_changes_for_vis["Change in Percent from 2007 to 2008"]
#topGDPincreasestates = gdp_07_08


plt.scatter(unemploy_07_08, pov_07_08, marker="o", facecolors="red", edgecolors="black", alpha=0.75)  #

#plt.scatter(gdp_07_08[, pov_07_08, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)

plt.xlim(-4, 3)
plt.ylim(-6, 8)


plt.title("2007-2008: Change in Unemployment Rate vs. Change in Poverty %")
plt.xlabel("Change in Unemployment Rate")
plt.ylabel("Change in Poverty %")
#matplotlib.pyplot.grid(which='major', axis='both')
plt.grid(True)   

plt.savefig("07_08_pov_unemp.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
# %matplotlib notebook
# Scatter plot showing the relationship between %unemployment and Poverty (2007-2008)
economic_df_states2 = economic_df_states.drop([0, 331, 332, 3196])
#print(economic_df_states2)
#gdp_for_visualization2 = gdp_for_visualization.drop(gdp_for_visualization.index[8])
#gdp_for_visualization2  #dropped DC from Charlie's data

unemploy_08_17 = economic_df_states2["Rate Change from 2008 to 2017"]
pov_08_17 = poverty_changes_for_vis["Change in Percent from 2008 to 2017"]
#topGDPincreasestates = gdp_07_08


plt.scatter(unemploy_08_17, pov_08_17, marker="o", facecolors="red", edgecolors="black", alpha=0.75)  #

#plt.scatter(gdp_07_08[, pov_07_08, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)

plt.xlim(-4, 3)
plt.ylim(-6, 8)


plt.title("2008-2017: Change in Unemployment Rate vs. Change in Poverty %")
plt.xlabel("Change in Unemployment Rate")
plt.ylabel("Change in Poverty %")
#matplotlib.pyplot.grid(which='major', axis='both')
plt.grid(True)   
plt.savefig("08_17_pov_unemp.png")
#plt.show()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">
